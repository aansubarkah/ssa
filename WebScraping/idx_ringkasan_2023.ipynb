# %%
import json
import pandas as pd
import time
import glob, os, requests

from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

from datetime import datetime, timedelta

# %% [markdown]
# # Buka Browser

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.idx.co.id/id/data-pasar/ringkasan-perdagangan/ringkasan-indeks')

# %%
S = requests.Session()

# %%
S.cookies.update({c['name']: c['value'] for c in driver.get_cookies()})

# %%
S.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='_cfuvid', value='ko6mb8V9_5.rG.VBPMM.ck.v53UPNYZFbHKb1tK3noo-1730431025888-0.0.1.1-604800000', port=None, port_specified=False, domain='', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='_ga', value='GA1.3.1764426960.1730431027', port=None, port_specified=False, domain='', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='_ga_VDBWS0BLZR', value='GS1.1.1730431026.1.0.1730431026.0.0.0', port=None, port_specified=False, domain='', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='auth.strategy', value='local', port=None, port_specified=False, domain='', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='_gid', value='GA1.3.1964698759.1730431027', port=None, port_specified=False, domain='', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='__cf_bm', value='ftNUqBbfGFrLH2PtIXQQv1Kv4RuJoYx3o7SKuw_ixJ8-1730431025-1.0.1.1-4fcoJGSr0JCVFNrl_b0cgLn2_I5PFVbfNeiati3PRTTS.ciMMqotopb45.tXHfEf47UnSE8nbHXFzZRHSavP_g', port=None, port_specified=False, domain='', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False)]>

# %% [markdown]
# # Ambil 1 Data

# %%
headers = {
    'Accept': 'application/json, text/plain, */*',
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Host': 'www.idx.co.id',
    'Connection': 'keep-alive',
    'Priority': 'u-1,i',
    'Referer': 'https://www.idx.co.id/id/data-pasar/ringkasan-perdagangan/ringkasan-indeks',
    'Sec-Ch-Ua': '"Chromium";v="130", "Google Chrome";v="130", "Not?A_Brand";v="99"',
    'Sec-Ch-Ua-Mobile': '?0',
    'Sec-Ch-Ua-Platform': '"Windows"',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36'
}

# %%
r = S.get('https://www.idx.co.id/primary/TradingSummary/GetIndexSummary?date=20241101&length=9999&start=0', headers=headers)

# %%
r.status_code
# Out:
# 403

# %%
#r.json()

# %% [markdown]
# # Buat Dir

# %%
new_dir = 'idx_data_2020'
os.makedirs(new_dir, exist_ok=True)

# %% [markdown]
# # Buat Tanggal

# %%
start_date = datetime(2023, 1, 1)
end_date = datetime(2024, 1, 1)
#end_date = datetime.today()

# %%
url_start = 'https://www.idx.co.id/primary/TradingSummary/GetIndexSummary?date='
url_end = '&length=9999&start=0'

current_date = start_date
while current_date <= end_date:
    try:
        cur_date = current_date.strftime('%Y%m%d')
        print(cur_date)

        url_to = url_start + cur_date + url_end
        driver.get(url_to)

        teks = driver.find_element(By.TAG_NAME, 'pre')
        data_in_json = json.loads(teks.text)
        with open(f'{new_dir}/{cur_date}.json', 'w') as f:
            json.dump(data_in_json['data'], f, indent=4)

        #r = S.get(url_to, headers=headers)
        #if r.status_code == 200:
            #with open(f'{new_dir}/{cur_date}.json', 'w') as f:
                #json.dump(r.json(), f)

        #else:
            #print('Error, status code', cur_date)
        time.sleep(1)
    except:
        print('Error', cur_date)

    current_date += timedelta(days=1)
# Out:
# 20230101
# 20230102
# 20230103
# 20230104
# 20230105
# 20230106
# 20230107
# 20230108
# 20230109
# 20230110
# 20230111
# 20230112
# 20230113
# 20230114
# 20230115
# 20230116
# 20230117
# 20230118
# 20230119
# 20230120
# 20230918
# 20230919
# 20230920
# 20230921
# 20230922
# 20230923
# 20230924
# 20230925
# 20230926
# 20230927
# 20230928
# 20230929
# 20230930
# 20231001
# 20231002
# 20231003
# 20231004
# 20231005
# 20231006
# 20231007
# 20231008
# 20231009
# 20231010
# 20231011
# 20231012
# 20231013
# 20231014
# 20231015
# 20231016
# 20231017
# 20231018
# 20231019
# 20231020
# 20231021
# 20231022
# 20231023
# 20231024
# 20231025
# 20231026
# 20231027
# 20231028
# 20231029
# 20231030
# 20231031
# 20231101
# 20231102
# 20231103
# 20231104
# 20231105
# 20231106
# 20231107
# 20231108
# 20231109
# 20231110
# 20231111
# 20231112
# 20231113
# 20231114
# 20231115
# 20231116
# 20231117
# 20231118
# 20231119
# 20231120
# 20231121
# 20231122
# 20231123
# 20231124
# 20231125
# 20231126
# 20231127
# 20231128
# 20231129
# 20231130
# 20231201
# 20231202
# 20231203
# 20231204
# 20231205
# 20231206
# 20231207
# 20231208
# 20231209
# 20231210
# 20231211
# 20231212
# 20231213
# 20231214
# 20231215
# 20231216
# 20231217
# 20231218
# 20231219
# 20231220
# 20231221
# 20231222
# 20231223
# 20231224
# 20231225
# 20231226
# 20231227
# 20231228
# 20231229
# 20231230
# 20231231
# 20240101

# %% [markdown]
# # Ambil 1 Data

# %%
driver.get('https://www.idx.co.id/primary/TradingSummary/GetIndexSummary?date=20240802&length=9999&start=0')

# %%
teks = driver.find_element(By.TAG_NAME, 'pre')

# %%
#teks.text

# %%
data_in_json = json.loads(teks.text)

# %%
#data_in_json['data']

# %%
with open('ini_json.json', 'w', encoding='utf-8') as f:
    json.dump(data_in_json['data'], f, indent=4)

# %%
df = pd.DataFrame(data_in_json['data'])

# %%
df.to_excel('ini_dari_json.xlsx', index=False)

# %%
df
# Out:
#     No  IndexSummaryID                 Date   IndexCode  Previous   Highest  \
# 0    1          172451  2024-08-02T00:00:00   COMPOSITE  7325.985  7337.981
# 1    2          172452  2024-08-02T00:00:00        LQ45   925.505   925.160
# 2    3          172492  2024-08-02T00:00:00  IDXLQ45LCL   128.040   128.169
# 3    4          172461  2024-08-02T00:00:00       IDX30   461.447   461.912
# 4    5          172472  2024-08-02T00:00:00       IDX80   129.283   129.250
# 5    6          172476  2024-08-02T00:00:00     IDXESGL   162.704   163.604
# 6    7          172475  2024-08-02T00:00:00      IDXQ30   154.732   154.846
# 7    8          172473  2024-08-02T00:00:00      IDXV30   132.056   133.103
# 8    9          172474  2024-08-02T00:00:00      IDXG30   151.508   151.496
# 9   10          172469  2024-08-02T00:00:00  IDXHIDIV20   553.115   555.085
# 10  11          172470  2024-08-02T00:00:00   IDXBUMN20   389.852   391.210
# 11  12          172471  2024-08-02T00:00:00       JII70   182.975   183.298
# 12  13          172460  2024-08-02T00:00:00        ISSI   218.948   219.410
# 13  14          172453  2024-08-02T00:00:00         JII   514.790   514.156
# 44  1374.562  1377.065           34.0 -14.514  1.956284e+08  5.216298e+10
#
#     Frequency  MarketCapital
# 0    894972.0   1.241034e+16
# 1    304143.0   6.078793e+15
# 2    215030.0   4.502138e+15
# 3    247910.0   4.639554e+15
# 4    397077.0   6.933566e+15
# 5    198989.0   4.642793e+15
# 6    198593.0   4.080157e+15
# 7    117174.0   8.851684e+14
# 8    177535.0   3.879852e+15
# 9    189533.0   5.049515e+15
# 10   136589.0   2.256552e+15
# 11   318031.0   4.535631e+15
# 12   662361.0   6.949397e+15
# 13   197845.0   2.877383e+15
# 14    76337.0   6.663300e+14
# 15   144238.0   1.495198e+15
# 16   168819.0   1.140598e+15
# 17   415927.0   3.063750e+15
# 18   553003.0   1.007892e+16
# 19   297549.0   1.990402e+15
# 20     7646.0   5.971844e+12
# 21   434293.0   8.000306e+15
# 22    89374.0   3.121464e+15
# 23   216404.0   4.480763e+15
# 24   226142.0   5.489474e+15
# 25   160182.0   3.827082e+15
# 26   245273.0   4.538856e+15
# 27   202954.0   4.427400e+15
# 28   132262.0   2.304410e+15
# 29   225653.0   4.699930e+15
# 30   176299.0   4.718196e+15
# 31    74463.0   3.459433e+14
# 32    79269.0   3.012177e+15
# 33   174381.0   4.389950e+15
# 34   102614.0   1.533136e+15
# 35   133796.0   2.414849e+15
# 36    35704.0   3.585938e+14
# 37   130462.0   1.024743e+15
# 38   104326.0   4.097348e+14
# 39    36693.0   2.857706e+14
# 40   116315.0   3.762599e+15
# 41    81854.0   3.312808e+14
# 42    32928.0   2.880064e+14
# 43    87409.0   1.955582e+15
# 44    23152.0   3.948662e+13

# %%
start_date = datetime(2024, 8, 1)
end_date = datetime(2024, 8, 31)

cur_date = start_date

url_depan = 'https://www.idx.co.id/primary/TradingSummary/GetIndexSummary?date='
url_belakang = '&length=9999&start=0'

while cur_date <= end_date:
    print(cur_date.strftime('%Y%m%d'))

    url = url_depan + cur_date.strftime('%Y%m%d') + url_belakang

    #print(url)

    driver.get(url)

    teks = driver.find_element(By.TAG_NAME, 'pre')
    data_in_json = json.loads(teks.text)
    with open('idx_31_agustus/' + cur_date.strftime('%Y%m%d')+ '.json', 'w', encoding='utf-8') as f:
        json.dump(data_in_json['data'], f, indent=4)
    
    time.sleep(1)
    
    cur_date = cur_date + timedelta(days=1)
# Out:
# 20240801
# 20240802
# 20240803
# 20240804
# 20240805
# 20240806
# 20240807
# 20240808
# 20240809
# 20240810
# 20240811
# 20240812
# 20240813
# 20240814
# 20240815
# 20240816
# 20240817
# 20240818
# 20240819
# 20240820
# 20240821
# 20240822
# 20240823
# 20240824
# 20240825
# 20240826
# 20240827
# 20240828
# 20240829
# 20240830
# 20240831

# %%
data_ls = []

for file in os.listdir('idx_31_agustus'):
    if file.endswith('json'):
        print(file)

        with open('idx_31_agustus/' + file, 'r') as f:
            data = json.load(f)
            df_temp = pd.DataFrame(data)
            data_ls.append(df_temp)
            
            #data_ls.append(pd.DataFrame(data))
            
            
        #print(data)
df = pd.concat(data_ls)
# Out:
# 20240801.json
# 20240802.json
# 20240803.json
# 20240804.json
# 20240805.json
# 20240806.json
# 20240807.json
# 20240808.json
# 20240809.json
# 20240810.json
# 20240811.json
# 20240812.json
# 20240813.json
# 20240814.json
# 20240815.json
# 20240816.json
# 20240817.json
# 20240818.json
# 20240819.json
# 20240820.json
# 20240821.json
# 20240822.json
# 20240823.json
# 20240824.json
# 20240825.json
# 20240826.json
# 20240827.json
# 20240828.json
# 20240829.json
# 20240830.json
# 20240831.json

# %%
df
# Out:
#     No  IndexSummaryID                 Date   IndexCode  Previous   Highest  \
# 0    1          172406  2024-08-01T00:00:00   COMPOSITE  7255.762  7325.985
# 1    2          172407  2024-08-01T00:00:00        LQ45   913.713   926.026
# 2    3          172447  2024-08-01T00:00:00  IDXLQ45LCL   126.061   128.139
# 3    4          172416  2024-08-01T00:00:00       IDX30   454.759   461.510
# 4    5          172427  2024-08-01T00:00:00       IDX80   128.041   129.389
# ..  ..             ...                  ...         ...       ...       ...
# 40  41          173473  2024-08-30T00:00:00  IDXFINANCE  1475.279  1481.926
# 41  42          173474  2024-08-30T00:00:00  IDXPROPERT   724.640   728.337
# 42  43          173475  2024-08-30T00:00:00   IDXTECHNO  3241.863  3282.617
# 43  44          173476  2024-08-30T00:00:00    IDXINFRA  1609.606  1629.184
# 44  45          173477  2024-08-30T00:00:00    IDXTRANS  1434.485  1450.347
#
#       Lowest     Close  NumberOfStock  Change        Volume         Value  \
# 0   7258.874  7325.985          892.0  70.223  1.267156e+10  9.418643e+12
# 1    915.476   925.505           45.0  11.792  3.381597e+09  6.094184e+12
# 2    126.460   128.040           30.0   1.979  2.959963e+09  4.909773e+12
# 3    455.597   461.447           30.0   6.688  2.975239e+09  5.250584e+12
# 4    128.216   129.283           80.0   1.242  4.765501e+09  7.094412e+12
# ..       ...       ...            ...     ...           ...           ...
# 40  1470.858  1473.486          104.0  -1.793  2.428654e+09  6.042633e+12
# 41   716.999   721.906           89.0  -2.734  2.673814e+09  6.852379e+11
# 42  3233.996  3263.298           40.0  21.435  4.668960e+09  3.052881e+11
# 43  1608.224  1629.184           66.0  19.578  2.112985e+09  1.967978e+12
# 44  1431.337  1448.281           34.0  13.796  3.246676e+08  9.483462e+10
#
#     Frequency  MarketCapital
# 0    969288.0   1.243430e+16
# 1    308226.0   6.126090e+15
# 2    229235.0   4.539941e+15
# 3    246719.0   4.675889e+15
# 4    434515.0   6.982524e+15
# ..        ...            ...
# 40   158029.0   3.933141e+15
# 41   136763.0   3.910307e+14
# 42    31450.0   2.879812e+14
# 43   148483.0   2.272364e+15
# 44    35642.0   4.216386e+13
#
# [990 rows x 14 columns]

# %%
df.to_excel('ini_idx_agustus.xlsx', index=False)
