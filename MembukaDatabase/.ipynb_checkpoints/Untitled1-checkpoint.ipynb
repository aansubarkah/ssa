# %% [markdown]
# # Install Libraries

# %%
#!pip install pyodbc

# %%
#!pip install tabula-py

# %% [markdown]
# # Panggil Libraries

# %%
import pyodbc
import pandas as pd

# %% [markdown]
# # Buka Database

# %%
server = '146.190.109.222,1434'
database = 'AdventureWorks2019'
username = 'auditor'
password = 'basangdata'

# %%
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+password)
cursor = cnxn.cursor()

# %%
query = 'SELECT * FROM Sales.Customer;'
df_tabel_customer = pd.read_sql(query, cnxn)
# Out:
# C:\Users\aansubarkah\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df_tabel_customer
# Out:
#        CustomerID  PersonID  StoreID  TerritoryID AccountNumber  \
# 0               1       NaN    934.0            1    AW00000001
# 1               2       NaN   1028.0            1    AW00000002
# 2               3       NaN    642.0            4    AW00000003
# 3               4       NaN    932.0            4    AW00000004
# 4               5       NaN   1026.0            4    AW00000005
# ...           ...       ...      ...          ...           ...
# 19815       30114    1985.0   1986.0            7    AW00030114
# 19816       30115    1987.0   1988.0            6    AW00030115
# 19817       30116    1989.0   1990.0            4    AW00030116
# 19818       30117    1991.0   1992.0            4    AW00030117
# 19819       30118    1993.0   1994.0            3    AW00030118
#
#                                     rowguid            ModifiedDate
# 0      3F5AE95E-B87D-4AED-95B4-C3797AFCB74F 2014-09-12 11:15:07.263
# ...

# %% [markdown]
# ## Simpan ke CSV

# %%
df_tabel_customer.to_csv('kastemer_lain.csv', sep='\t', index=False)

# %% [markdown]
# # Filter Customer

# %%
df_tabel_customer_934 = df_tabel_customer[df_tabel_customer.StoreID == 934]

# %%
df_tabel_customer_934
# Out:
#        CustomerID  PersonID  StoreID  TerritoryID AccountNumber  \
# 0               1       NaN    934.0            1    AW00000001
# 19474       29773     933.0    934.0            1    AW00029773
#
#                                     rowguid            ModifiedDate
# 0      3F5AE95E-B87D-4AED-95B4-C3797AFCB74F 2014-09-12 11:15:07.263
# 19474  B956A64D-040C-4230-AC9B-B927F7DD1BA7 2014-09-12 11:15:07.263

# %% [markdown]
# # Buka data Excel

# %%
df_tabel_store = pd.read_excel('Store.xlsx')

# %%
df_tabel_store
# Out:
#      BusinessEntityID                            Name  SalesPersonID  \
# 0                 292            Next-Door Bike Store            279
# 1                 294  Professional Sales and Service            276
# 2                 296                  Riders Company            277
# 3                 298              The Bike Mechanics            275
# 4                 300               Nationwide Supply            286
# ..                ...                             ...            ...
# 696              1988                     Retreat Inn            282
# 697              1990   Technical Parts Manufacturing            281
# 698              1992         Totes & Baskets Company            277
# 699              1994                  World of Bikes            277
# 700              2051           A Bicycle Association            275
#
#                                           Demographics  \
# 0    <StoreSurvey xmlns="http://schemas.microsoft.c...
# ...

# %%
df_tabel_store_online = pd.read_excel('https://github.com/aansubarkah/sekolahsabtuauditor/raw/main/MembukaDatabase/Store.xlsx')

# %%
df_tabel_store_online
# Out:
#      BusinessEntityID                            Name  SalesPersonID  \
# 0                 292            Next-Door Bike Store            279
# 1                 294  Professional Sales and Service            276
# 2                 296                  Riders Company            277
# 3                 298              The Bike Mechanics            275
# 4                 300               Nationwide Supply            286
# ..                ...                             ...            ...
# 696              1988                     Retreat Inn            282
# 697              1990   Technical Parts Manufacturing            281
# 698              1992         Totes & Baskets Company            277
# 699              1994                  World of Bikes            277
# 700              2051           A Bicycle Association            275
#
#                                           Demographics  \
# 0    <StoreSurvey xmlns="http://schemas.microsoft.c...
# ...

# %%
df_db_excel = df_tabel_customer_934.merge(df_tabel_store, left_on='StoreID', right_on='BusinessEntityID')

# %%
df_db_excel
# Out:
#    CustomerID  PersonID  StoreID  TerritoryID AccountNumber  \
# 0           1       NaN    934.0            1    AW00000001
# 1       29773     933.0    934.0            1    AW00029773
#
#                               rowguid_x          ModifiedDate_x  \
# 0  3F5AE95E-B87D-4AED-95B4-C3797AFCB74F 2014-09-12 11:15:07.263
# 1  B956A64D-040C-4230-AC9B-B927F7DD1BA7 2014-09-12 11:15:07.263
#
#    BusinessEntityID          Name  SalesPersonID  \
# 0               934  A Bike Store            280
# 1               934  A Bike Store            280
#
#                                         Demographics  \
# 0  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 1  <StoreSurvey xmlns="http://schemas.microsoft.c...
#
#                               rowguid_y          ModifiedDate_y
# 0  80B15702-DF20-4DF9-876C-2CF1C3978D39 2014-09-12 11:15:07.497
# 1  80B15702-DF20-4DF9-876C-2CF1C3978D39 2014-09-12 11:15:07.497

# %% [markdown]
# # Buka PDF

# %%
import tabula

# %%
df_tabel_sales = tabula.read_pdf('SalesPerson.pdf', pages='all')

# %%
df_tabel_sales[0]
# Out:
#     BusinessEntityID  TerritoryID  SalesQuota  Bonus CommissionPct  \
# 0                274          NaN         NaN      0             0
# 1                275          2.0    300000.0   4100         0,012
# 2                276          4.0    250000.0   2000         0,015
# 3                277          3.0    250000.0   2500         0,015
# 4                278          6.0    250000.0    500          0,01
# 5                279          5.0    300000.0   6700          0,01
# 6                280          1.0    250000.0   5000          0,01
# 7                281          4.0    250000.0   3550          0,01
# 8                282          6.0    250000.0   5000         0,015
# 9                283          1.0    250000.0   3500         0,012
# 10               284          1.0    300000.0   3900         0,019
# 11               285          NaN         NaN      0             0
# 12               286          9.0    250000.0   5650         0,018
# ...

# %%
df_tabel_sales_1 = df_tabel_sales[0]

# %%
df_tabel_sales_1
# Out:
#     BusinessEntityID  TerritoryID  SalesQuota  Bonus CommissionPct  \
# 0                274          NaN         NaN      0             0
# 1                275          2.0    300000.0   4100         0,012
# 2                276          4.0    250000.0   2000         0,015
# 3                277          3.0    250000.0   2500         0,015
# 4                278          6.0    250000.0    500          0,01
# 5                279          5.0    300000.0   6700          0,01
# 6                280          1.0    250000.0   5000          0,01
# 7                281          4.0    250000.0   3550          0,01
# 8                282          6.0    250000.0   5000         0,015
# 9                283          1.0    250000.0   3500         0,012
# 10               284          1.0    300000.0   3900         0,019
# 11               285          NaN         NaN      0             0
# 12               286          9.0    250000.0   5650         0,018
# ...

# %%
df_tabel_sales_1['TerritoryIDx10'] = df_tabel_sales_1['TerritoryID'] * 10

# %%
df_tabel_sales_1
# Out:
#     BusinessEntityID  TerritoryID  SalesQuota  Bonus CommissionPct  \
# 0                274          NaN         NaN      0             0
# 1                275          2.0    300000.0   4100         0,012
# 2                276          4.0    250000.0   2000         0,015
# 3                277          3.0    250000.0   2500         0,015
# 4                278          6.0    250000.0    500          0,01
# 5                279          5.0    300000.0   6700          0,01
# 6                280          1.0    250000.0   5000          0,01
# 7                281          4.0    250000.0   3550          0,01
# 8                282          6.0    250000.0   5000         0,015
# 9                283          1.0    250000.0   3500         0,012
# 10               284          1.0    300000.0   3900         0,019
# 11               285          NaN         NaN      0             0
# 12               286          9.0    250000.0   5650         0,018
# ...

# %% [markdown]
# # Gabung DB x Excel x PDF

# %%
df_1_gabungan = df_db_excel.merge(df_tabel_sales_1, left_on='SalesPersonID', right_on='BusinessEntityID')

# %%
df_1_gabungan
# Out:
#    CustomerID  PersonID  StoreID  TerritoryID_x AccountNumber  \
# 0           1       NaN    934.0              1    AW00000001
# 1       29773     933.0    934.0              1    AW00029773
#
#                               rowguid_x          ModifiedDate_x  \
# 0  3F5AE95E-B87D-4AED-95B4-C3797AFCB74F 2014-09-12 11:15:07.263
# 1  B956A64D-040C-4230-AC9B-B927F7DD1BA7 2014-09-12 11:15:07.263
#
#    BusinessEntityID_x          Name  SalesPersonID  ... BusinessEntityID_y  \
# 0                 934  A Bike Store            280  ...                280
# 1                 934  A Bike Store            280  ...                280
#
#   TerritoryID_y SalesQuota  Bonus  CommissionPct     SalesYTD  SalesLastYear  \
# 0           1.0   250000.0   5000           0,01  1352577,133    1927059,178
# 1           1.0   250000.0   5000           0,01  1352577,133    1927059,178
#
#                                 rowguid      ModifiedDate TerritoryIDx10
# ...
