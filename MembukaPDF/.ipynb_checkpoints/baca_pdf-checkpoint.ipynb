# %%
#!pip install tabula-py

# %%
#!pip install pdfplumber

# %%
# !pip install tabula-py pdfplumber
# Out:
# Requirement already satisfied: tabula-py in c:\users\aansubarkah\anaconda3\lib\site-packages (2.9.3)
# Requirement already satisfied: pdfplumber in c:\users\aansubarkah\anaconda3\lib\site-packages (0.11.3)
# Requirement already satisfied: distro in c:\users\aansubarkah\anaconda3\lib\site-packages (from tabula-py) (1.9.0)
# Requirement already satisfied: numpy in c:\users\aansubarkah\anaconda3\lib\site-packages (from tabula-py) (1.26.4)
# Requirement already satisfied: pandas>=0.25.3 in c:\users\aansubarkah\anaconda3\lib\site-packages (from tabula-py) (2.2.2)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\aansubarkah\anaconda3\lib\site-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: Pillow>=9.1 in c:\users\aansubarkah\anaconda3\lib\site-packages (from pdfplumber) (10.4.0)
# Requirement already satisfied: pdfminer.six==20231228 in c:\users\aansubarkah\anaconda3\lib\site-packages (from pdfplumber) (20231228)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\aansubarkah\anaconda3\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (43.0.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\aansubarkah\anaconda3\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (3.3.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aansubarkah\anaconda3\lib\site-packages (from pandas>=0.25.3->tabula-py) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aansubarkah\anaconda3\lib\site-packages (from pandas>=0.25.3->tabula-py) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aansubarkah\anaconda3\lib\site-packages (from pandas>=0.25.3->tabula-py) (2024.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\aansubarkah\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\aansubarkah\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.25.3->tabula-py) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\aansubarkah\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.22)

# %% [markdown]
# # Import Libraries

# %%
import tabula
import pdfplumber
import pandas as pd

# %% [markdown]
# # PDF isi Tabel

# %% [markdown]
# ## Baca PDF

# %%
pdf_tabel = tabula.read_pdf("Store.pdf", pages="all")
# Out:
# Failed to import jpype dependencies. Fallback to subprocess.
# No module named 'jpype'

# %% [markdown]
# Teknis:
#
# - pdf_tabel adalah list/array berisi variabel tabel.
# - List dimulai dari angka 0
# - Panjang/besar list adalah jumlah variabel dalam list tersebut, pdf_tabel memiliki panjang 15, sesuai jumlah halaman PDF.

# %%
#pdf_tabel

# %% [markdown]
# <strong>pdf_table</strong> berisi semua halaman PDF. Untuk melihat masing-masing halaman, gunakan <strong>nama_variabel[angka] (pdf_tabel[0])</strong>.

# %%
pdf_tabel[0]
# Out:
#     BusinessEntityID                                 Name  SalesPersonID  \
# 0                292                 Next-Door Bike Store            279
# 1                294       Professional Sales and Service            276
# 2                296                       Riders Company            277
# 3                298                   The Bike Mechanics            275
# 4                300                    Nationwide Supply            286
# 5                302                Area Bike Accessories            281
# 6                304         Bicycle Accessories and Kits            283
# 7                306                Clamps & Brackets Co.            275
# 8                308           Valley Bicycle Specialists            277
# 9                310                    New Bikes Company            279
# 10               312  Vinyl and Plastic Goods Corporation            282
# 11               314                Top of the Line Bikes            288
# 12               316                   Fun Toys and Bikes            281
# 13               318                          Great Bikes            283
# 14               320        Metropolitan Sales and Rental            275
# 15               322                    Irregulars Outlet            288
# 16               324                     Valley Toy Store            282
# 17               326            Worthwhile Activity Store            279
# 18               328                        Purchase Mart            275
# 19               330                Major Sport Suppliers            283
# 20               332          Family's Favorite Bike Shop            278
# 21               334                         Global Plaza            279
# 22               336         Imported and Domestic Cycles            276
# 23               338                     Systematic Sales            281
# 24               340                      eCommerce Bikes            279
# 25               342                   Mountain Toy Store            277
# 26               344             Retail Sales and Service            275
# 27               346              Designated Distributors            282
# 28               348                Bold Bike Accessories            276
# 29               350                          Twin Cycles            286
# 30               352                   Tiny Bike Boutique            279
# 31               354            Acclaimed Bicycle Company            279
# 32               356                       Serious Cycles            278
# 33               358                   Quality Bike Sales            286
# 34               360                        Novelty Bikes            275
# 35               362   Distinctive Cycles Sales & Service            279
# 36               364            Leading Bike Distributors            279
# 37               366                      Activity Center            279
# 38               368                   Brightwork Company            281
# 39               370                      Resale Services            276
# 40               372                       The Gear Store            277
# 41               374        Immense Manufacturing Company            277
# 42               376                  Extended Bike Sales            276
# 43               378                  Pedaling Components            288
# 44               380                     Workout Emporium            282
# 45               382            Work and Play Association            275
# 46               384                   Seaside Bike Works            286
# 47               386                           Nice Bikes            278
# 48               388                Remarkable Bike Store            276
#
#                                          Demographics  \
# 0   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 1   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 2   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 3   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 4   <StoreSurvey xmlns="http://schemas.microsoft.c...
#
ve1n2u/0e9>/820001040 <1/1A:1n5n
# 37  e1ve2n/0u9e/>21051040 0101<:1/5A
# 38  e1ve2n/0u9e/>21051040 0101<:1/5A
# 39  ve1n2u/0e9>/820001040 <1/1A:1n5n
# 40  ve1n2u/0e9>/820001040 <1/1A:1n5n
# 41  e1ve2n/0u9e/>23001040 0101<:1/5A
# 42  e1ve2n/0u9e/>23001040 0101<:1/5A
# 43  e1ve2n/0u9e/>21051040 0101<:1/5A
# 44  e1ve2n/0u9e/>21051040 0101<:1/5A
# 45  ve1n2u/0e9>/820001040 <1/1A:1n5n
# 46  ve1n2u/0e9>/820001040 <1/1A:1n5n
# 47  ve1n2u/0e9>/320001040 <1/1A:1n5n
# 48  ve1n2u/0e9>/820001040 <1/1A:1n5n

# %%
pdf_tabel[2]
# Out:
#     490           Commuter Bicycle Store  282  \
# 0   492           Coalition Bike Company  281
# 1   494                   Travel Systems  277
# 2   496  Grease and Oil Products Company  277
# 3   498    Moderately-Priced Bikes Store  280
# 4   500            Toy Manufacturing Inc  278
# 5   502                Eighty Toy Stores  279
# 6   504            Economy Bikes Company  276
# 7   506                 Third Bike Store  277
# 8   508            Atypical Bike Company  290
# 9   510                    Bikes for Two  282
# 10  512         Metal Processing Company  278
# 11  514       Widget Bicycle Specialists  279
# 12  516             Initial Bike Company  281
# 13  518          Latest Sports Equipment  283
# 14  520                Modern Bike Store  275
# 15  522                Raw Materials Inc  280
# 16  524         Lots of Bikes Storehouse  277
# 17  526                 Futuristic Bikes  281
# 18  528  Parcel Express Delivery Service  283
# 19  530             Outdoor Distributors  275
# 20  532               North Bike Company  288
# 21  534                 Prosperous Tours  289
# 22  536             Nonskid Tire Company  280
# 23  538           Amalgamated Parts Shop  288
# 24  540                 Metro Bike Works  275
# 25  542                    Best o' Bikes  277
# 26  544     Painters Bicycle Specialists  275
# 27  546            Client Discount Store  277
# 28  548          Eastside Sporting Goods  275
# 29  550               Helmets and Cycles  286
# 30  552            Requisite Part Supply  282
# 31  554       Racks and Security Systems  279
# 32  556         Mechanical Products Ltd.  281
# 33  558                Commendable Bikes  283
# 34  560              Online Bike Sellers  275
# 35  562       Custom Accessories Company  278
# 36  564          Unusual Bicycle Company  286
# 37  566    Courteous Bicycle Specialists  282
# 38  568                      Hobby Store  279
# 39  570         Professional Cycle Store  281
# 40  572                    Bike Universe  281
# 41  574                 Fifth Bike Store  283
# 42  576               Independent Outlet  275
# 43  578                   Rambling Tours  288
# 44  580              Farthest Bike Store  282
# 45  582                  Excellent Bikes  288
# 46  584                Curbside Universe  275
# 47  586             Alternative Vehicles  280
# 48  588                   Channel Outlet  289
#
#    <StoreSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/StoreSurve  \
# 0   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 1   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 2   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 3   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 4   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 5   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 6   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 7   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 8   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 9   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 10  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 11  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 12  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 13  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 14  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 15  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 16  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 17  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 18  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 19  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 20  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 21  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 22  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 23  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 24  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 25  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 26  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 27  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 28  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 29  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 30  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 31  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 32  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 33  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 34  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 35  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 36  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 37  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 38  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 39  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 40  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 41  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 42  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 43  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 44  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 45  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 46  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 47  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 48  <StoreSurvey xmlns="http://schemas.microsoft.c...
#
ve1n2u/0e9>/820001040 <1/1A:1n5n
# 44  e1ve2n/0u9e/>23001040 0101<:1/5A
# 45  e1ve2n/0u9e/>23001040 0101<:1/5A
# 46  e1ve2n/0u9e/>23001040 0101<:1/5A
# 47  e1ve2n/0u9e/>21051040 0101<:1/5A
# 48  e1ve2n/0u9e/>21051040 0101<:1/5A

# %% [markdown]
# ## Tambah Nama Kolom pada halaman 2-15

# %% [markdown]
# Halaman kedua (pdf_tabel[1]) tidak memiliki judul kolom, sehingga baris pertama dianggap sebagai judul. Cara perbaiki

# %% [markdown]
# ### Cari tahu tipe variabel pdf_tabel

# %%
type(pdf_tabel[1])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Google dengan kata kunci "Pandas rename column name"

# %%
#pdf_tabel[1].columns = ['BusinessEntityID', 'Name', 'SalesPersonID', 'Demographics', 'rowguid', 'ModifiedDate']

# %%
pdf_tabel[1]
# Out:
#     390                       Road-Way Mart  283  \
# 0   392                   Small Cycle Store  275
# 1   394            Blue-Ribbon Bike Company  279
# 2   396                  Flawless Bike Shop  276
# 3   398                Grand Bicycle Stores  277
# 4   400            Exertion Activities Club  281
# 5   402                     Impromptu Trips  283
# 6   404                     Margie's Travel  275
# 7   406                   Kickstand Sellers  275
# 8   408                  Nearest Bike Store  286
# 9   410                     Fast Bike Works  286
# 10  412                  Gasless Cycle Shop  278
# 11  414      Lubricant and Grease Suppliers  279
# 12  416                 Teen Discount Store  288
# 13  418              Transportation Options  282
# 14  420             Capital Riding Supplies  288
# 15  422                       Bike Boutique  275
# 16  424                       Bikes Anyone?  275
# 17  426               Cross-town Parts Shop  286
# 18  428                    Finer Cycle Shop  278
# 19  430                   Center Cycle Shop  280
# 20  432                 Bulk Discount Store  289
# 21  434                  Country Parts Shop  290
# 22  436                    Second Bike Shop  286
# 23  438                   First-Rate Outlet  278
# 24  440           Juvenile Sports Equipment  279
# 25  442             Another Bicycle Company  283
# 26  444                   Fourth Bike Store  275
# 27  446                  Rodeway Bike Store  288
# 28  448               Traction Tire Company  276
# 29  450                   Unsurpassed Bikes  277
# 30  452                      Field Trip Inc  275
# 31  454                        Tire Company  275
# 32  456           Uncompromising Quality Co  286
# 33  458      Metallic Paint and Overcoat Co  281
# 34  460                  Pro Sporting Goods  276
# 35  462     Sporting Goods and Bicycle Shop  279
# 36  464   Odometers and Accessories Company  278
# 37  466  Scratch-Resistant Finishes Company  282
# 38  468                      Topnotch Bikes  279
# 39  470  Unicycles, Bicycles, and Tricycles  281
# 40  472                    Safe Cycles Shop  283
# 41  474                     Number 1 Supply  281
# 42  476                 Industrial Supplies  279
# 43  478                Golf and Cycle Store  281
# 44  480                  Front Runner Bikes  279
# 45  482            Favorite Toy Distributor  290
# 46  484           World Bike Discount Store  276
# 47  486               Global Sporting Goods  277
# 48  488              Historic Bicycle Sales  275
#
#    <StoreSurvey xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/StoreSurve  \
# 0   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 1   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 2   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 3   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 4   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 5   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 6   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 7   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 8   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 9   <StoreSurvey xmlns="http://schemas.microsoft.c...
# 10  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 11  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 12  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 13  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 14  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 15  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 16  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 17  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 18  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 19  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 20  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 21  <StoreSurvey xmlns="http://schemas.microsoft.c...
#
ve1n2u/0e9>/820001040 <1/1A:1n5n
# 38  ve1n2u/0e9>/820001040 <1/1A:1n5n
# 39  ve1n2u/0e9>/820001040 <1/1A:1n5n
# 40  e1ve2n/0u9e/>23001040 0101<:1/5A
# 41  e1ve2n/0u9e/>23001040 0101<:1/5A
# 42  e1ve2n/0u9e/>23001040 0101<:1/5A
# 43  e1ve2n/0u9e/>23001040 0101<:1/5A
# 44  e1ve2n/0u9e/>23001040 0101<:1/5A
# 45  e1ve2n/0u9e/>23001040 0101<:1/5A
# 46  e1ve2n/0u9e/>21051040 0101<:1/5A
# 47  e1ve2n/0u9e/>21051040 0101<:1/5A
# 48  e1ve2n/0u9e/>21051040 0101<:1/5A

# %% [markdown]
# Baris bertama, dengan Name Road-Way Mart, hilang. Sebelumnya data itu menjadi judul kolom.

# %% [markdown]
# Google: pandas set column name as first row
#
# Solusi: Load ulang dari PDF

# %%
tabel_2 = pdf_tabel[1].reset_index().T.reset_index().T

tabel_2 = tabel_2.iloc[:, 1:]

tabel_2.columns = ['BusinessEntityID', 'Name', 'SalesPersonID', 'Demographics', 'rowguid', 'ModifiedDate']

# %%
tabel_2
# Out:
#       BusinessEntityID                                Name SalesPersonID  \
# index              390                       Road-Way Mart           283
# 0                  392                   Small Cycle Store           275
# 1                  394            Blue-Ribbon Bike Company           279
# 2                  396                  Flawless Bike Shop           276
# 3                  398                Grand Bicycle Stores           277
# 4                  400            Exertion Activities Club           281
# 5                  402                     Impromptu Trips           283
# 6                  404                     Margie's Travel           275
# 7                  406                   Kickstand Sellers           275
# 8                  408                  Nearest Bike Store           286
# 9                  410                     Fast Bike Works           286
# 10                 412                  Gasless Cycle Shop           278
# 11                 414      Lubricant and Grease Suppliers           279
# 12                 416                 Teen Discount Store           288
# 13                 418              Transportation Options           282
# 14                 420             Capital Riding Supplies           288
# 15                 422                       Bike Boutique           275
# 16                 424                       Bikes Anyone?           275
# 17                 426               Cross-town Parts Shop           286
# 18                 428                    Finer Cycle Shop           278
# 19                 430                   Center Cycle Shop           280
# 20                 432                 Bulk Discount Store           289
# 21                 434                  Country Parts Shop           290
# 22                 436                    Second Bike Shop           286
# 23                 438                   First-Rate Outlet           278
# 24                 440           Juvenile Sports Equipment           279
# 25                 442             Another Bicycle Company           283
# 26                 444                   Fourth Bike Store           275
# 27                 446                  Rodeway Bike Store           288
# 28                 448               Traction Tire Company           276
# 29                 450                   Unsurpassed Bikes           277
# 30                 452                      Field Trip Inc           275
# 31                 454                        Tire Company           275
# 32                 456           Uncompromising Quality Co           286
# 33                 458      Metallic Paint and Overcoat Co           281
# 34                 460                  Pro Sporting Goods           276
# 35                 462     Sporting Goods and Bicycle Shop           279
# 36                 464   Odometers and Accessories Company           278
# 37                 466  Scratch-Resistant Finishes Company           282
# 38                 468                      Topnotch Bikes           279
# 39                 470  Unicycles, Bicycles, and Tricycles           281
# 40                 472                    Safe Cycles Shop           283
# 41                 474                     Number 1 Supply           281
# 42                 476                 Industrial Supplies           279
# 43                 478                Golf and Cycle Store           281
# 44                 480                  Front Runner Bikes           279
# 45                 482            Favorite Toy Distributor           290
# 46                 484           World Bike Discount Store           276
# 47                 486               Global Sporting Goods           277
# 48                 488              Historic Bicycle Sales           275
#
#                                             Demographics  \
# index  <StoreSurvey xmlns="http://schemas.microsoft.c...
#
ve1n2u/0e9>/820001040 <1/1A:1n5n
# 14     e1ve2n/0u9e/>21051040 0101<:1/5A
# 15     e1ve2n/0u9e/>21051040 0101<:1/5A
# 16     e1ve2n/0u9e/>21001040 0101<:1/5A
# 17     ve1n2u/0e9>/820001040 <1/1A:1n5n
# 18     ve1n2u/0e9>/820001040 <1/1A:1n5n
# 19     e1ve2n/0u9e/>21001040 1001<:1/5A
# 20     ve1n2u/0e9>/820001040 <1/1A:1n5n
# 21     ve1n2u/0e9>/820001040 <1/1A:1n5n
# 22     ve1n2u/0e9>/820001040 <1/1A:1n5n
# 23     e1ve2n/0u9e/>21001040 0101<:1/5A
# 24     ve1n2u/0e9>/820001040 <1/1A:1n5n
# 25     ve1n2u/0e9>/320001040 <1/1A:1n5n
# 26     ve1n2u/0e9>/320001040 <1/1A:1n5n
# 27     ve1n2u/0e9>/320001040 <1/1A:1n5n
# 28     e1ve2n/0u9e/>21051040 0101<:1/5A
# 29     e1ve2n/0u9e/>21051040 0101<:1/5A
# 30     e1ve2n/0u9e/>21051040 0101<:1/5A
# 31     e1ve2n/0u9e/>21051040 0101<:1/5A
# 32     e1ve2n/0u9e/>21051040 0101<:1/5A
# 33     e1ve2n/0u9e/>21001040 0101<:1/5A
# 34     e1ve2n/0u9e/>23001040 0101<:1/5A
# 35     e1ve2n/0u9e/>23001040 0101<:1/5A
# 36     e1ve2n/0u9e/>23001040 0101<:1/5A
# 37     ve1n2u/0e9>/820001040 <1/1A:1n5n
# 38     ve1n2u/0e9>/820001040 <1/1A:1n5n
# 39     ve1n2u/0e9>/820001040 <1/1A:1n5n
# 40     e1ve2n/0u9e/>23001040 0101<:1/5A
# 41     e1ve2n/0u9e/>23001040 0101<:1/5A
# 42     e1ve2n/0u9e/>23001040 0101<:1/5A
# 43     e1ve2n/0u9e/>23001040 0101<:1/5A
# 44     e1ve2n/0u9e/>23001040 0101<:1/5A
# 45     e1ve2n/0u9e/>23001040 0101<:1/5A
# 46     e1ve2n/0u9e/>21051040 0101<:1/5A
# 47     e1ve2n/0u9e/>21051040 0101<:1/5A
# 48     e1ve2n/0u9e/>21051040 0101<:1/5A

# %% [markdown]
# ## Gabungkan semua halaman menjadi satu variabel/dataframe/tabel

# %% [markdown]
# Google: Pandas concat dataframe

# %% [markdown]
# Kata kunci: Interation/For loop/Perulangan

# %%
pdf_tabel = tabula.read_pdf("Store.pdf", pages="all")

list_tabel = []

#for i in range(0, 6): # mulai dari halaman 1 sampai halaman akhir pdf, lakukan hal di bawah ini
for i in range(0, len(pdf_tabel)): # mulai dari halaman 1 sampai halaman akhir pdf, lakukan hal di bawah ini     
    if i == 0:
        list_tabel.append(pdf_tabel[i])
    else:
        # tambahkan judul kolom
        tabel_2 = pdf_tabel[i].reset_index().T.reset_index().T
        tabel_2 = tabel_2.iloc[:, 1:]
        tabel_2.columns = ['BusinessEntityID', 'Name', 'SalesPersonID', 'Demographics', 'rowguid', 'ModifiedDate']

        # masukkan dalam ember
        list_tabel.append(tabel_2)

tabel_pdf = pd.concat(list_tabel, ignore_index=True)

# %%
#list_tabel[1]

# %%
tabel_pdf
# Out:
#     BusinessEntityID                                 Name SalesPersonID  \
# 0                292                 Next-Door Bike Store           279
# 1                294       Professional Sales and Service           276
# 2                296                       Riders Company           277
# 3                298                   The Bike Mechanics           275
# 4                300                    Nationwide Supply           286
# ..               ...                                  ...           ...
# 294              880                        The Bike Shop           283
# 295              882                            Safe Toys           281
# 296              884  Qualified Sales and Repair Services           279
# 297              886             Our Sporting Goods Store           282
# 298              888       Lustrous Paints and Components           288
#
#                                           Demographics  \
# 0    <StoreSurvey xmlns="http://schemas.microsoft.c...
# 1    <StoreSurvey xmlns="http://schemas.microsoft.c...
# 2    <StoreSurvey xmlns="http://schemas.microsoft.c...
# 3    <StoreSurvey xmlns="http://schemas.microsoft.c...
# 4    <StoreSurvey xmlns="http://schemas.microsoft.c...
# ..                                                 ...
# 294  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 295  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 296  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 297  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 298  <StoreSurvey xmlns="http://schemas.microsoft.c...
#
#                                                rowguid  \
# 0    A">2<2A5n17nEu3a-lS8a4l8eDs>-48E0B0E0-0B09<D/A...
# 1    B">5<0ACAnn5u0Bal-SCa6le0s1>-48A001030-B00<7/A...
# 2    3"3>7<CA3n6n8u8a-lS1a3l3e9s->48E010A0-0A00<8/A...
# 3    7"8>9<4AFn2n7u8a-lFS0aCle8s->48D01060-0B0D<7/5...
# 4    C"3>F<CA9n7n0u5a-lASa8lCe4s>-48F030A0-0905<5/0...
# ..                                                 ...
# 294  E"A><9A81n0nDuaBl-S8aFl7es3>-4340E080-0B0605<A...
# 295  3"B><4A9BnAnu1a3l-S2aFl3e9s>-43408010-080105<3...
# 296  0"8>A<A0EnBn5u6a-lSAa8le8s1>-438080F0-0A0400<8...
# 297  A">E<7ABn04n5u9a-lS9a3lBe0s>-43010B0-080102<8/...
# 298  2"E>9<0A9nFn3u7a-l9SDal2e7s->4309000-0B0400<F/...
#
#                          ModifiedDate
# 0    ve1n2u/0e9>/820001040 <1/1A:1n5n
# 1    ve1n2u/0e9>/820001040 <1/1A:1n5n
# 2    ve1n2u/0e9>/820001040 <1/1A:1n5n
# 3    ve1n2u/0e9>/820001040 <1/1A:1n5n
# 4    ve1n2u/0e9>/820001040 <1/1A:1n5n
# ..                                ...
# 294  e1ve2n/0u9e/>23001040 0101<:1/5A
# 295  e1ve2n/0u9e/>23001040 0101<:1/5A
# 296  e1ve2n/0u9e/>23001040 0101<:1/5A
# 297  e1ve2n/0u9e/>23001040 0101<:1/5A
# 298  e1ve2n/0u9e/>23001040 0101<:1/5A
#
# [299 rows x 6 columns]

# %% [markdown]
# ## Simpan hasil

# %%
tabel_pdf.to_excel('dari_pdf_tabel_baru_lagi_17_agutsut_error.xlsx', index=False)

# %%
tabel_pdf.to_csv('dari_pdf_tabel.csv', index=False)

# %% [markdown]
# # PDF Tidak Terstruktur

# %% [markdown]
# ## Buka Satu File

# %%
with pdfplumber.open('banyak_pdfs\\STATISTIK PERBANKAN SYARIAH APRIL 2024.pdf') as pdf:
    pages = pdf.pages
    
    for i in range(len(pages)):
        #print(i)
        page = pdf.pages[i]
        #table = page.extract_table()
        #df = pd.DataFrame(table)
        #print(df)
        texts = page.extract_text()

        for line in texts.split('\n'):
            if 'NPF (%)' in line:
                print(line)
# Out:
# NPF (%) 3.13 2.59 2 .35 2 .38 2 .36 2 .36 2 .36 2 .32 2 .28 2 .24 2 .20 2 .10 2.11 2 .05 2 .04 2 .05
# NPF (%) 3 .01 2 .55 2 .23 2 .17 2 .17 2 .15 2 .09 2 .10 2 .03 2 .03 2 .04 1 .93 2 .03 2 .09 2 .09 2 .27

# %% [markdown]
# ### Pola

# %% [markdown]
# - PDF memiliki banyak halaman
# - Angka yang di cari diawali/kata "NPF (%)"
# - Di bawah "Tabel 1a"
# - Di atas "Tabel 1b"
# - Pada angka, ada spasi di kiri titik desimal, hapus
# - Ada 16 angka
# - 3 angka pertama adalah 4 tahun dari tahun laporan, perlu tahu tahun laporan
# - 13 angka adalah angka 13 bulan sampai dengan bulan laporan, perlu tahu bulan laporan
# - Bulan laporan ada di halaman pertama, teks terakhir. Perlu konversi text jadi month. Teks bulan dalam Bahasa Indonesia

# %% [markdown]
# ### Hapus spasi sebelum desimal

# %%
#with pdfplumber.open('banyak_pdfs\\STATISTIK PERBANKAN SYARIAH APRIL 2024.pdf') as pdf:
#    pages = pdf.pages
#    for i in range(len(pages)):
#        page = pdf.pages[i]
#        texts = page.extract_text()

        #for line in texts.split('\n'):
            #if 'NPF (%)' in line:
                #print(line.replace(' .', '.'))
# Out:
# NPF (%) 3.13 2.59 2.35 2.38 2.36 2.36 2.36 2.32 2.28 2.24 2.20 2.10 2.11 2.05 2.04 2.05
# NPF (%) 3.01 2.55 2.23 2.17 2.17 2.15 2.09 2.10 2.03 2.03 2.04 1.93 2.03 2.09 2.09 2.27

# %% [markdown]
# ### Ambil hanya NPF pertama

# %%
npf_belum_ketemu = True # [baru]
#npf_ke = 0
#ini_variable_npf_5 = ''
#print('pertama:', ini_variable_npf_5)

with pdfplumber.open('banyak_pdfs\\STATISTIK PERBANKAN SYARIAH APRIL 2024.pdf') as pdf:
    pages = pdf.pages
    
    for i in range(len(pages)):
        #if npf_belum_ketemu == False:
            #print('tidak lakukan apa2')
        if npf_belum_ketemu == True:
            page = pdf.pages[i]
            texts = page.extract_text()

            for line in texts.split('\n'):
                if 'NPF (%)' in line:
                    print('ketemu')
                    npf_belum_ketemu = False
                    #print(line.replace(' .', '.'))
                    #npf_ke = npf_ke + 1
                    #print(npf_ke)
                    #if npf_ke == 6:
                        #print('ini adalah npf ke-5', line)
                        #ini_variable_npf_5 = line                        
                        # ini bisa diganti/ditambah prosedur/algoritma sesuai kebutuhan                        
                        #npf_belum_ketemu = False # [baru] jika ditemukan teks NPF (%) maka tidak perlu lagi membaca halaman lainnya
                        
                        
#print('kedua:', ini_variable_npf_5)
# Out:
# ketemu

# %% [markdown]
# ### Ambil Tahun dan Bulan Laporan

# %%
npf_belum_ketemu = True
with pdfplumber.open('banyak_pdfs\\STATISTIK PERBANKAN SYARIAH APRIL 2024.pdf') as pdf:
    pages = pdf.pages
    
    # [baru] mencari tahun dan bulan di halaman pertama
    page = pdf.pages[0]
    texts = page.extract_text()
    for line in texts.split('\n'):
        if line:
            print(line)
        
    for i in range(len(pages)):
        if npf_belum_ketemu: # [baru]
            page = pdf.pages[i]
            texts = page.extract_text()

            for line in texts.split('\n'):
                if 'NPF (%)' in line:
                    print(line.replace(' .', '.'))
                    npf_belum_ketemu = False # [baru] jika ditemukan teks NPF (%) maka tidak perlu lagi membaca halaman lainnya
# Out:
# APRIL 2024
# April2024
# NPF (%) 3.13 2.59 2.35 2.38 2.36 2.36 2.36 2.32 2.28 2.24 2.20 2.10 2.11 2.05 2.04 2.05

# %% [markdown]
# Ternyata di halaman pertama hanya ada 2 baris teks. Baris terakhir berisi tahun dan bulan (dalam bahasa Inggris) dalam 1 kata. Teks itu yg mau diambil

# %%
npf_belum_ketemu = True
npf_teks = '' # [baru]

bulan_teks = '' # [baru]
with pdfplumber.open('banyak_pdfs\\STATISTIK PERBANKAN SYARIAH MEI 2024.pdf') as pdf:
    pages = pdf.pages
    # mencari tahun dan bulan di halaman pertama
    page = pdf.pages[0]
    texts = page.extract_text()
    for line in texts.split('\n'):
        if line:
            # print(line)
            bulan_teks = line # [baru]
        
    for i in range(len(pages)):
        if npf_belum_ketemu:
            page = pdf.pages[i]
            texts = page.extract_text()

            for line in texts.split('\n'):
                if 'NPF (%)' in line:
                    # print(line.replace(' .', '.'))
                    npf_teks = line.replace(' .', '.') # [baru]
                    npf_belum_ketemu = False # jika ditemukan teks NPF (%) maka tidak perlu lagi membaca halaman lainnya

print(bulan_teks) # [baru]
print(npf_teks) # [baru]
# Out:
# May2024
# NPF (%) 3.13 2.59 2.35 2.36 2.36 2.36 2.32 2.28 2.24 2.20 2.10 2.11 2.05 2.04 2.05 2.10

# %% [markdown]
# #### Konversi teks ke Bulan Tahun

# %% [markdown]
# Google: python text to month year

# %%
from datetime import datetime, date

# %%
date_obj = datetime.strptime(bulan_teks, '%b%Y')

# %% [markdown]
# Format bulan, tahun (%b %Y)
#
# https://help.gnome.org/users/gthumb/stable/gthumb-date-formats.html.en

# %%
date_obj
# Out:
# datetime.datetime(2024, 5, 1, 0, 0)

# %%
npf_belum_ketemu = True
npf_teks = '' # [baru]

bulan_teks = ''
with pdfplumber.open('banyak_pdfs\\STATISTIK PERBANKAN SYARIAH MEI 2024.pdf') as pdf:
    pages = pdf.pages
    # mencari tahun dan bulan di halaman pertama
    page = pdf.pages[0]
    texts = page.extract_text()
    for line in texts.split('\n'):
        if line:
            # print(line)
            bulan_teks = line # [baru]

    for i in range(len(pages)):
        if npf_belum_ketemu:
            page = pdf.pages[i]
            texts = page.extract_text()

            for line in texts.split('\n'):
                if 'NPF (%)' in line:
                    # print(line.replace(' .', '.'))
                    npf_teks = line.replace(' .', '.') # [baru]
                    npf_belum_ketemu = False # jika ditemukan teks NPF (%) maka tidak perlu lagi membaca halaman lainnya

tahun = 0 # [baru]
bulan = 0 # [baru]

bulan_tahun = datetime.strptime(bulan_teks, '%b%Y') # [baru]
tahun = bulan_tahun.year # [baru]
bulan = bulan_tahun.month # [baru]

print(bulan_teks, tahun, bulan) # [baru]
print(npf_teks)
# Out:
# May2024 2024 5
# NPF (%) 3.13 2.59 2.35 2.36 2.36 2.36 2.32 2.28 2.24 2.20 2.10 2.11 2.05 2.04 2.05 2.10

# %% [markdown]
# ### Tiga Tahun Pertama

# %%
npf_belum_ketemu = True
npf_teks = ''

bulan_teks = ''
with pdfplumber.open('banyak_pdfs\\STATISTIK PERBANKAN SYARIAH MEI 2024.pdf') as pdf:
    pages = pdf.pages
    # mencari tahun dan bulan di halaman pertama
    page = pdf.pages[0]
    texts = page.extract_text()
    for line in texts.split('\n'):
        if line:
            # print(line)
            bulan_teks = line

    for i in range(len(pages)):
        if npf_belum_ketemu:
            page = pdf.pages[i]
            texts = page.extract_text()

            for line in texts.split('\n'):
                if 'NPF (%)' in line:
                    # print(line.replace(' .', '.'))
                    npf_teks = line.replace(' .', '.')
                    npf_belum_ketemu = False # jika ditemukan teks NPF (%) maka tidak perlu lagi membaca halaman lainnya

tahun = 0
bulan = 0

bulan_tahun = datetime.strptime(bulan_teks, '%b%Y')
tahun = bulan_tahun.year
bulan = bulan_tahun.month

print(bulan_teks, tahun, bulan)
print(npf_teks)

# baru
npf_teks_list = npf_teks.split()
print('ini npf_teks_split', npf_teks_list)

tahun_4 = npf_teks_list[2]
tahun_3 = npf_teks_list[3]
tahun_2 = npf_teks_list[4]

print(tahun_4, tahun_3, tahun_2)
# Out:
# May2024 2024 5
# NPF (%) 3.13 2.59 2.35 2.36 2.36 2.36 2.32 2.28 2.24 2.20 2.10 2.11 2.05 2.04 2.05 2.10
# ini npf_teks_split ['NPF', '(%)', '3.13', '2.59', '2.35', '2.36', '2.36', '2.36', '2.32', '2.28', '2.24', '2.20', '2.10', '2.11', '2.05', '2.04', '2.05', '2.10']
# 3.13 2.59 2.35

# %% [markdown]
# ### Tiga Belas Bulan Terakhir

# %%
npf_belum_ketemu = True
npf_teks = ''

bulan_teks = ''
with pdfplumber.open('banyak_pdfs\\STATISTIK PERBANKAN SYARIAH MEI 2024.pdf') as pdf:
    pages = pdf.pages
    # mencari tahun dan bulan di halaman pertama
    page = pdf.pages[0]
    texts = page.extract_text()
    for line in texts.split('\n'):
        if line:
            # print(line)
            bulan_teks = line

    for i in range(len(pages)):
        if npf_belum_ketemu:
            page = pdf.pages[i]
            texts = page.extract_text()

            for line in texts.split('\n'):
                if 'NPF (%)' in line:
                    # print(line.replace(' .', '.'))
                    npf_teks = line.replace(' .', '.')
                    npf_belum_ketemu = False # jika ditemukan teks NPF (%) maka tidak perlu lagi membaca halaman lainnya

tahun = 0
bulan = 0

bulan_tahun = datetime.strptime(bulan_teks, '%b%Y')
tahun = bulan_tahun.year
bulan = bulan_tahun.month

print(bulan_teks, tahun, bulan)
print(npf_teks)

npf_teks_list = npf_teks.split()
print(npf_teks_list)

tahun_4 = npf_teks_list[2]
tahun_3 = npf_teks_list[3]
tahun_2 = npf_teks_list[4]

print(tahun_4, tahun_3, tahun_2)

# baru
bulan_13 = npf_teks_list[5:]
print('ini, bulan_13', bulan_13)

# buat dictionary/dict/objek semacam kamus
data_dict = {}
# pola dictionary: nama_kolom -> isi (value)
data_dict['tahun_' + str(tahun - 4)] = tahun_4
data_dict['tahun_' + str(tahun - 3)] = tahun_3
data_dict['tahun_' + str(tahun - 2)] = tahun_2

print('ini data_dict', data_dict)

tahun_1_sisa_bulan = 13 - bulan
print('ini sisa bulan tahun n-1', tahun_1_sisa_bulan)

tahun_1_mulai_bulan = 13 - tahun_1_sisa_bulan
print('ini bulan mulai ditampilkan, untuk tahun n-1', tahun_1_mulai_bulan)

idx = 0
for bln in range(tahun_1_mulai_bulan, 13):
    # print(date(tahun-1, bulan, 1).strftime('%b_%Y'))
    # data_dict[date(tahun-1, bln, 1).strftime('%b_%Y')] = bulan_13.pop(0)
    data_dict[date(tahun-1, bln, 1).strftime('%b_%Y')] = bulan_13[idx]
    idx += 1

for bln in range(1, bulan+1):
    # print(date(tahun, bln, 1).strftime('%b_%Y'))
    #data_dict[date(tahun, bln, 1).strftime('%b_%Y')] = bulan_13.pop(0)
    data_dict[date(tahun, bln, 1).strftime('%b_%Y')] = bulan_13[idx]
    idx += 1


print(data_dict)

df = pd.DataFrame([data_dict])
# Out:
# May2024 2024 5
# NPF (%) 3.13 2.59 2.35 2.36 2.36 2.36 2.32 2.28 2.24 2.20 2.10 2.11 2.05 2.04 2.05 2.10
# ['NPF', '(%)', '3.13', '2.59', '2.35', '2.36', '2.36', '2.36', '2.32', '2.28', '2.24', '2.20', '2.10', '2.11', '2.05', '2.04', '2.05', '2.10']
# 3.13 2.59 2.35
# ini, bulan_13 ['2.36', '2.36', '2.36', '2.32', '2.28', '2.24', '2.20', '2.10', '2.11', '2.05', '2.04', '2.05', '2.10']
# ini data_dict {'tahun_2020': '3.13', 'tahun_2021': '2.59', 'tahun_2022': '2.35'}
# ini sisa bulan tahun n-1 8
# ini bulan mulai ditampilkan, untuk tahun n-1 5
# {'tahun_2020': '3.13', 'tahun_2021': '2.59', 'tahun_2022': '2.35', 'May_2023': '2.36', 'Jun_2023': '2.36', 'Jul_2023': '2.36', 'Aug_2023': '2.32', 'Sep_2023': '2.28', 'Oct_2023': '2.24', 'Nov_2023': '2.20', 'Dec_2023': '2.10', 'Jan_2024': '2.11', 'Feb_2024': '2.05', 'Mar_2024': '2.04', 'Apr_2024': '2.05', 'May_2024': '2.10'}

# %%
df
# Out:
#   tahun_2020 tahun_2021 tahun_2022 May_2023 Jun_2023 Jul_2023 Aug_2023  \
# 0       3.13       2.59       2.35     2.36     2.36     2.36     2.32
#
#   Sep_2023 Oct_2023 Nov_2023 Dec_2023 Jan_2024 Feb_2024 Mar_2024 Apr_2024  \
# 0     2.28     2.24     2.20     2.10     2.11     2.05     2.04     2.05
#
#   May_2024
# 0     2.10

# %% [markdown]
# ## Buka Banyak File dalam Folder

# %%
import os, glob

# %%
for file in glob.glob('banyak_pdfs\\*.pdf'):
    print(file)
# Out:
# banyak_pdfs\STATISTIK PERBANKAN SYARIAH - JANUARI 2024.pdf
# banyak_pdfs\STATISTIK PERBANKAN SYARIAH - MARET 2024.pdf
# banyak_pdfs\STATISTIK PERBANKAN SYARIAH APRIL 2024.pdf
# banyak_pdfs\STATISTIK PERBANKAN SYARIAH MEI 2024.pdf

# %%
df_list = []

for file in glob.glob('banyak_pdfs\\*.pdf'):
    print(file)
    
    npf_belum_ketemu = True
    npf_teks = ''

    bulan_teks = ''
    with pdfplumber.open(file) as pdf:
    #with pdfplumber.open('banyak_pdfs\\STATISTIK PERBANKAN SYARIAH MEI 2024.pdf') as pdf:
        pages = pdf.pages
        # mencari tahun dan bulan di halaman pertama
        page = pdf.pages[0]
        texts = page.extract_text()
        for line in texts.split('\n'):
            if line:
                # print(line)
                bulan_teks = line.replace(' ', '')

        for i in range(len(pages)):
            if npf_belum_ketemu:
                page = pdf.pages[i]
                texts = page.extract_text()

                for line in texts.split('\n'):
                    if 'NPF (%)' in line:
                        # print(line.replace(' .', '.'))
                        npf_teks = line.replace(' .', '.')
                        npf_belum_ketemu = False # jika ditemukan teks NPF (%) maka tidak perlu lagi membaca halaman lainnya

    tahun = 0
    bulan = 0

    bulan_tahun = datetime.strptime(bulan_teks, '%B%Y')
    tahun = bulan_tahun.year
    bulan = bulan_tahun.month

    #print(bulan_teks, tahun, bulan)
    #print(npf_teks)

    npf_teks_list = npf_teks.split()
    #print(npf_teks_list)

    
    if len(npf_teks_list) == 18:
        tahun_4 = npf_teks_list[2]
        tahun_3 = npf_teks_list[3]
        tahun_2 = npf_teks_list[4]
        bulan_13 = npf_teks_list[5:]
        
    if len(npf_teks_list) == 17:
        tahun_4 = 0
        tahun_3 = npf_teks_list[2]
        tahun_2 = npf_teks_list[3]
        bulan_13 = npf_teks_list[3:]
        
    #print(tahun_4)
    #print(npf_teks_list)
    #print(bulan_13)
    
    #print(tahun_4, tahun_3, tahun_2)

    # baru
    #bulan_13 = npf_teks_list[5:]
    #print(bulan_13)

    # buat dictionary/dict/objek semacam kamus
    data_dict = {}
    data_dict['tahun_' + str(tahun-4)] = tahun_4
    data_dict['tahun_' + str(tahun-3)] = tahun_3
    data_dict['tahun_' + str(tahun-2)] = tahun_2

    #print(data_dict)

    tahun_1_sisa_bulan = 13 - bulan
    #print(tahun_1_sisa_bulan)

    tahun_1_mulai_bulan = 13 - tahun_1_sisa_bulan
    #print(tahun_1_mulai_bulan)

    #print(bulan_13)
    idx = 0
    for bln in range(tahun_1_mulai_bulan, 13):
        # print(date(tahun-1, bulan, 1).strftime('%b_%Y'))
        # data_dict[date(tahun-1, bln, 1).strftime('%b_%Y')] = bulan_13.pop(0)
        data_dict[date(tahun-1, bln, 1).strftime('%b_%Y')] = bulan_13[idx]
        idx += 1

    for bln in range(1, bulan+1):
        # print(date(tahun, bln, 1).strftime('%b_%Y'))
        #data_dict[date(tahun, bln, 1).strftime('%b_%Y')] = bulan_13.pop(0)
        data_dict[date(tahun, bln, 1).strftime('%b_%Y')] = bulan_13[idx]
        idx += 1

    #print(data_dict)

    temp_df = pd.DataFrame([data_dict])
    df_list.append(temp_df)
# Out:
# banyak_pdfs\STATISTIK PERBANKAN SYARIAH - DESEMBER 2023.pdf
# banyak_pdfs\STATISTIK PERBANKAN SYARIAH - FEBRUARI 2024.pdf
# banyak_pdfs\STATISTIK PERBANKAN SYARIAH - JANUARI 2024.pdf
# banyak_pdfs\STATISTIK PERBANKAN SYARIAH - MARET 2024.pdf
# banyak_pdfs\STATISTIK PERBANKAN SYARIAH - NOVEMBER 2023.pdf
# banyak_pdfs\STATISTIK PERBANKAN SYARIAH - SEPTEMBER 2023.pdf
# banyak_pdfs\STATISTIK PERBANKAN SYARIAH APRIL 2024.pdf
# banyak_pdfs\STATISTIK PERBANKAN SYARIAH MEI 2024.pdf

# %%
df = pd.concat(df_list, ignore_index=True)

# %%
df
# Out:
#   tahun_2019 tahun_2020 tahun_2021 Dec_2022 Jan_2023 Feb_2023 Mar_2023  \
# 0          0       3.13       2.59     2.59     2.35     2.41     2.37
# 1        NaN       3.13       2.59      NaN      NaN     2.37     2.38
# 2        NaN       3.13       2.59      NaN     2.41     2.37     2.38
# 3        NaN       3.13       2.59      NaN      NaN      NaN     2.38
# 4       3.13       2.59       2.54     2.35     2.41     2.37     2.38
# 5       3,13       2,59       2,57     2,41     2,37     2,38     2,38
# 6        NaN       3.13       2.59      NaN      NaN      NaN      NaN
# 7        NaN       3.13       2.59      NaN      NaN      NaN      NaN
#
#   Apr_2023 May_2023 Jun_2023  ... Dec_2023 tahun_2022 Jan_2024 Feb_2024  \
# 0     2.38     2.38     2.36  ...     2.20        NaN      NaN      NaN
# 1     2.38     2.36     2.36  ...     2.10       2.35     2.11     2.05
# 2     2.38     2.36     2.36  ...     2.10       2.35     2.11      NaN
# 3     2.38     2.36     2.36  ...     2.10       2.35     2.11     2.05
# 4     2.38     2.36     2.36  ...      NaN        NaN      NaN      NaN
# 5        2      ,36     2,36  ...      NaN        NaN      NaN      NaN
# 6     2.38     2.36     2.36  ...     2.10       2.35     2.11     2.05
# 7      NaN     2.36     2.36  ...     2.10       2.35     2.11     2.05
#
#   Mar_2024 Nov_2022 Sep_2022 Oct_2022 Apr_2024 May_2024
# 0      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN
# 3     2.04      NaN      NaN      NaN      NaN      NaN
# 4      NaN     2.50      NaN      NaN      NaN      NaN
# 5      NaN     2,35     2,54     2,50      NaN      NaN
# 6     2.04      NaN      NaN      NaN     2.05      NaN
# 7     2.04      NaN      NaN      NaN     2.05     2.10
#
# [8 rows x 25 columns]

# %%
df.to_excel('dari_ojk_baru_2023_17_agus_baru.xlsx', index=False)

# %% [markdown]
# # Kode di bawah ini Gagal

# %%
#pdf1 = tabula.read_pdf("banyak_pdfs\\STATISTIK PERBANKAN SYARIAH APRIL 2024.pdf", pages='all')

# %%
#!pip install jpype1
