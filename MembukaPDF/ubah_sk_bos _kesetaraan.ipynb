# %%
import tabula, math, PyPDF2
import pandas as pd

from tqdm.notebook import tqdm

# %%
#pdf_tabel = tabula.read_pdf("Salinan Lampiran 4 Kepmendikbudristek BOS Kesetaraan.pdf", pages="all")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File CommandLineApp.java:106, in technology.tabula.CommandLineApp.extractTables()
#
# Exception: Java Exception
#
# The above exception was the direct cause of the following exception:
#
# java.lang.OutOfMemoryError                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pdf_tabel = tabula.read_pdf("Salinan Lampiran 3 Kepmendikbudristek BOS.pdf", pages="all")
#
# File c:\Users\aansubarkah\anaconda3\envs\basangdata12\Lib\site-packages\tabula\io.py:395, in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, use_raw_url, pages, guess, area, relative_area, lattice, stream, password, silent, columns, relative_columns, format, batch, output_path, force_subprocess, options)
#     392     raise ValueError(f"{path} is empty. Check the file, or download it manually.")
#     394 try:
# --> 395     output = _run(
#     396         tabula_options,
#     397         java_options,
#     398         path,
#     399         encoding=encoding,
#     400         force_subprocess=force_subprocess,
#     401     )
#     402 finally:
#     403     if temporary:
#
# File c:\Users\aansubarkah\anaconda3\envs\basangdata12\Lib\site-packages\tabula\io.py:82, in _run(options, java_options, path, encoding, force_subprocess)
#      79 elif set(java_options) - IGNORED_JAVA_OPTIONS:
#      80     logger.warning("java_options is ignored until rebooting the Python process.")
# ---> 82 return _tabula_vm.call_tabula_java(options, path)
#
# File c:\Users\aansubarkah\anaconda3\envs\basangdata12\Lib\site-packages\tabula\backend.py:73, in TabulaVm.call_tabula_java(self, options, path)
#      70     args.insert(0, path)
#      72 cmd = self.parser.parse(self.tabula.CommandLineApp.buildOptions(), args)
# ---> 73 self.tabula.CommandLineApp(sb, cmd).extractTables(cmd)
#      74 return str(sb.toString())
#
# java.lang.OutOfMemoryError: java.lang.OutOfMemoryError: Java heap space

# %%
# Open the PDF file
with open("Salinan Lampiran 4 Kepmendikbudristek BOP Kesetaraan.pdf", 'rb') as file:
    # Create a PDF reader object
    pdf_reader = PyPDF2.PdfReader(file)
    # Get the number of pages
    total_pages = len(pdf_reader.pages)
    print(f"Total pages in PDF: {total_pages}")
# Out:
# Total pages in PDF: 601

# %%
pdf_info = tabula.read_pdf("Salinan Lampiran 4 Kepmendikbudristek BOP Kesetaraan.pdf", pages='1')
#total_pages = 5000
chunk_size = 10
total_chunks = math.ceil(total_pages / chunk_size)
print(f"Total chunks needed: {total_chunks}")
# Out:
# Total chunks needed: 61

# %%
all_tables = []
for chunk in tqdm(range(total_chunks), desc="Processing PDF chunks"):
    start_page = chunk * chunk_size + 1
    end_page = min((chunk + 1) * chunk_size, total_pages)
    
    try:
        # Read chunk of pages
        chunk_tables = tabula.read_pdf(
            "Salinan Lampiran 4 Kepmendikbudristek BOP Kesetaraan.pdf",
            pages=f"{start_page}-{end_page}"
        )
        # Extend the list with new tables
        all_tables.extend(chunk_tables)
    except Exception as e:
        print(f"Error processing pages {start_page}-{end_page}: {str(e)}")
        continue

# Combine all tables into pdf_tabel
pdf_tabel = pd.concat(all_tables, ignore_index=True)
# Out:
# Processing PDF chunks:   0%|          | 0/61 [00:00<?, ?it/s]

# %%
pdf_tabel
# Out:
#       Unnamed: 0     Unnamed: 1 Unnamed: 2    Nomor   Unnamed: 3  \
# 0            NaN      Provinsi/        NaN      NaN          NaN
# 1            NaN  Bentuk Satuan        NaN    Pokok  Nama Satuan
# 2          Nomor     Kabupaten/        NaN      NaN          NaN
# 3            NaN     Pendidikan        NaN  Sekolah   Pendidikan
# 4            NaN           Kota        NaN      NaN          NaN
# ...          ...            ...        ...      ...          ...
# 10679         78      1.300.000  1.500.000      NaN    1.800.000
# 10680         69      1.300.000  1.500.000      NaN    1.800.000
# 10681          8      1.300.000  1.500.000      NaN    1.800.000
# 10682         33      1.300.000  1.500.000      NaN    1.800.000
# 10683         71      1.300.000  1.500.000      NaN    1.800.000
#
#                           Unnamed: 4               Unnamed: 5   Unnamed: 6  \
# 0               Jumlah Peserta Didik    Satuan Biaya (Rupiah)          NaN
# 1                                NaN                      NaN          NaN
# 2                                NaN                      NaN          NaN
# 3                                NaN                      NaN          NaN
# 4      Paket A Paket B Paket C Total  Paket A Paket B Paket C      Paket A
# ...                              ...                      ...          ...
# 10679                      6.500.000               24.000.000  102.600.000
# 10680                              -               22.500.000   97.200.000
# 10681                              -                        -   14.400.000
# 10682                      1.300.000               28.500.000   23.400.000
# 10683                      3.900.000               19.500.000   99.000.000
#
#                                      Unnamed: 7 Provinsi/\rKabupaten\r/Kota  \
# 0      Besaran Alokasi Dana Satu Tahun (Rupiah)                         NaN
# 1                                           NaN                         NaN
# 2                                           NaN                         NaN
# 3                                           NaN                         NaN
# 4         Paket B Paket C Total Besaran Alokasi                         NaN
# ...                                         ...                         ...
# 10679                                93.600.000                         NaN
# 10680                                93.600.000                         NaN
# 10681                                93.600.000                         NaN
# 10682                                93.600.000                         NaN
# 10683                                93.600.000                         NaN
#
#                 Bentuk Satuan\rPendidikan Nomor\rPokok\rSekolah\rNasional  \
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# ...                                   ...                             ...
# 10679  Pusat Kegiatan\rBelajar Masyarakat                        P2965021
# 10680  Pusat Kegiatan\rBelajar Masyarakat                        P2966884
# 10681  Pusat Kegiatan\rBelajar Masyarakat                        P9934457
# 10682  Pusat Kegiatan\rBelajar Masyarakat                        P9984821
# 10683  Pusat Kegiatan\rBelajar Masyarakat                        P9998551
#
#                      Nama Satuan\rPendidikan Jumlah Peserta Didik  \
# 0                                        NaN                  NaN
# 1                                        NaN                  NaN
# 2                                        NaN                  NaN
# 3                                        NaN                  NaN
# 4                                        NaN                  NaN
# ...                                      ...                  ...
# 10679                            PKBM CAHAYA                    5
# 10680                        PKBM WIRABANGSA                    -
# 10681                             PKBM BUNDA                    -
# 10682        PKBM SRI MELAYU\rSUMATERA TIMUR                    1
# 10683  PKBM SWASTA\rRAUDHATUL\rHASANAH KARIM                    3
#
#       Satuan Biaya (Rupiah) Besaran Alokasi Dana Satu Tahun (Rupiah)
# 0                       NaN                                      NaN
# 1                       NaN                                      NaN
# 2                       NaN                                      NaN
# 3                       NaN                                      NaN
# 4                       NaN                                      NaN
# ...                     ...                                      ...
# 10679                    16                                       57
# 10680                    15                                       54
# 10681                     -                                        8
# 10682                    19                                       13
# 10683                    13                                       55
#
# [10684 rows x 16 columns]

# %%
pdf_tabel.columns = [
    'nomor',
    'wilayah',
    'bentuk_pendidikan',
    'npsn',
    'nama_sekolah',
    'jumlah_pd_a',
    'jumlah_pd_b',
    'jumlah_pd_c',
    'jumlah_pd_total',
    'satuan_biaya_a',
    'satuan_biaya_b',
    'satuan_biaya_c',
    'alokasi_satu_tahun_a',
    'alokasi_satu_tahun_b',
    'alokasi_satu_tahun_c',
    'alokasi_satu_tahun_total',
]

# %%
pdf_tabel.head(10)
# Out:
#    nomor               wilayah bentuk_pendidikan      npsn nama_sekolah  \
# 0    NaN             Provinsi/               NaN       NaN          NaN
# 1    NaN         Bentuk Satuan               NaN     Pokok  Nama Satuan
# 2  Nomor            Kabupaten/               NaN       NaN          NaN
# 3    NaN            Pendidikan               NaN   Sekolah   Pendidikan
# 4    NaN                  Kota               NaN       NaN          NaN
# 5    NaN                   NaN               NaN  Nasional          NaN
# 6    (a)               (b) (c)               NaN       (d)          (e)
# 7      1                   NaN               NaN       NaN          NaN
# 8    NaN         Provinsi Aceh               NaN       NaN          NaN
# 9    NaN  Kabupaten Aceh Barat               NaN       NaN          NaN
#
#                      jumlah_pd_a              jumlah_pd_b    jumlah_pd_c  \
# 0           Jumlah Peserta Didik    Satuan Biaya (Rupiah)            NaN
# 1                            NaN                      NaN            NaN
# 2                            NaN                      NaN            NaN
# 3                            NaN                      NaN            NaN
# 4  Paket A Paket B Paket C Total  Paket A Paket B Paket C        Paket A
# 5                            NaN                      NaN            NaN
# 6                (f) (g) (h) (i)              (j) (k) (l)            (m)
# 7                            NaN                      NaN            NaN
# 8       835  6.305 19.012 26.152                      NaN  1.122.300.000
# 9                   - 58 470 528                      NaN              -
#
#                                 jumlah_pd_total satuan_biaya_a satuan_biaya_b  \
# 0      Besaran Alokasi Dana Satu Tahun (Rupiah)            NaN            NaN
# 1                                           NaN            NaN            NaN
# 2                                           NaN            NaN            NaN
# 3                                           NaN            NaN            NaN
# 4         Paket B Paket C Total Besaran Alokasi            NaN            NaN
# 5                                           NaN            NaN            NaN
# 6                                   (n) (o) (p)            NaN            NaN
# 7                                           NaN            NaN            NaN
# 8  9.633.180.000  34.788.860.000 45.544.340.000            NaN            NaN
# 9            89.900.000 874.200.000 964.100.000            NaN            NaN
#
#   satuan_biaya_c alokasi_satu_tahun_a alokasi_satu_tahun_b  \
# 0            NaN                  NaN                  NaN
# 1            NaN                  NaN                  NaN
# 2            NaN                  NaN                  NaN
# 3            NaN                  NaN                  NaN
# 4            NaN                  NaN                  NaN
# 5            NaN                  NaN                  NaN
# 6            NaN                  NaN                  NaN
# 7            NaN                  NaN                  NaN
# 8            NaN                  NaN                  NaN
# 9            NaN                  NaN                  NaN
#
#   alokasi_satu_tahun_c alokasi_satu_tahun_total
# 0                  NaN                      NaN
# 1                  NaN                      NaN
# 2                  NaN                      NaN
# 3                  NaN                      NaN
# 4                  NaN                      NaN
# 5                  NaN                      NaN
# 6                  NaN                      NaN
# 7                  NaN                      NaN
# 8                  NaN                      NaN
# 9                  NaN                      NaN

# %%
# Skip first 8 rows and reset index
pdf_tabel = pdf_tabel.iloc[8:].reset_index(drop=True)

# %%
pdf_tabel
# Out:
#       nomor               wilayah bentuk_pendidikan      npsn   nama_sekolah  \
# 0       NaN         Provinsi Aceh               NaN       NaN            NaN
# 1       NaN  Kabupaten Aceh Barat               NaN       NaN            NaN
# 2       NaN        Pusat Kegiatan               NaN       NaN  PKBM MEUREUBO
# 3       NaN                   NaN               NaN  P9934727            NaN
# 4       NaN    Belajar Masyarakat               NaN       NaN        MANDIRI
# ...     ...                   ...               ...       ...            ...
# 10671    78             1.300.000         1.500.000       NaN      1.800.000
# 10672    69             1.300.000         1.500.000       NaN      1.800.000
# 10673     8             1.300.000         1.500.000       NaN      1.800.000
# 10674    33             1.300.000         1.500.000       NaN      1.800.000
# 10675    71             1.300.000         1.500.000       NaN      1.800.000
#
#                     jumlah_pd_a                       jumlah_pd_b  \
# 0      835  6.305 19.012 26.152                               NaN
# 1                  - 58 470 528                               NaN
# 2                           NaN                               NaN
# 3                   - 4 122 126  1.340.000  1.550.000  1 .860.000
# 4                           NaN                               NaN
# ...                         ...                               ...
# 10671                 6.500.000                        24.000.000
# 10672                         -                        22.500.000
# 10673                         -                                 -
# 10674                 1.300.000                        28.500.000
# 10675                 3.900.000                        19.500.000
#
#          jumlah_pd_c                               jumlah_pd_total  \
# 0      1.122.300.000  9.633.180.000  34.788.860.000 45.544.340.000
# 1                  -            89.900.000 874.200.000 964.100.000
# 2                NaN                                           NaN
# 3                  -             6.200.000 226.920.000 233.120.000
# 4                NaN                                           NaN
# ...              ...                                           ...
# 10671    102.600.000                                    93.600.000
# 10672     97.200.000                                    93.600.000
# 10673     14.400.000                                    93.600.000
# 10674     23.400.000                                    93.600.000
# 10675     99.000.000                                    93.600.000
#
#       satuan_biaya_a                      satuan_biaya_b satuan_biaya_c  \
# 0                NaN                                 NaN            NaN
# 1                NaN                                 NaN            NaN
# 2                NaN                                 NaN            NaN
# 3                NaN                                 NaN            NaN
# 4                NaN                                 NaN            NaN
# ...              ...                                 ...            ...
# 10671            NaN  Pusat Kegiatan\rBelajar Masyarakat       P2965021
# 10672            NaN  Pusat Kegiatan\rBelajar Masyarakat       P2966884
# 10673            NaN  Pusat Kegiatan\rBelajar Masyarakat       P9934457
# 10674            NaN  Pusat Kegiatan\rBelajar Masyarakat       P9984821
# 10675            NaN  Pusat Kegiatan\rBelajar Masyarakat       P9998551
#
#                         alokasi_satu_tahun_a alokasi_satu_tahun_b  \
# 0                                        NaN                  NaN
# 1                                        NaN                  NaN
# 2                                        NaN                  NaN
# 3                                        NaN                  NaN
# 4                                        NaN                  NaN
# ...                                      ...                  ...
# 10671                            PKBM CAHAYA                    5
# 10672                        PKBM WIRABANGSA                    -
# 10673                             PKBM BUNDA                    -
# 10674        PKBM SRI MELAYU\rSUMATERA TIMUR                    1
# 10675  PKBM SWASTA\rRAUDHATUL\rHASANAH KARIM                    3
#
#       alokasi_satu_tahun_c alokasi_satu_tahun_total
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
# ...                    ...                      ...
# 10671                   16                       57
# 10672                   15                       54
# 10673                    -                        8
# 10674                   19                       13
# 10675                   13                       55
#
# [10676 rows x 16 columns]

# %%
# Save to pickle format
pdf_tabel.to_pickle('pdf_tabel_bop_kesetaraan.pkl')

# Save to feather format
pdf_tabel.to_feather('pdf_tabel_bop_kesetaraan.feather')

# %%
pdf_tabel
# Out:
#       nomor               wilayah bentuk_pendidikan      npsn   nama_sekolah  \
# 0       NaN         Provinsi Aceh               NaN       NaN            NaN
# 1       NaN  Kabupaten Aceh Barat               NaN       NaN            NaN
# 2       NaN        Pusat Kegiatan               NaN       NaN  PKBM MEUREUBO
# 3       NaN                   NaN               NaN  P9934727            NaN
# 4       NaN    Belajar Masyarakat               NaN       NaN        MANDIRI
# ...     ...                   ...               ...       ...            ...
# 10671    78             1.300.000         1.500.000       NaN      1.800.000
# 10672    69             1.300.000         1.500.000       NaN      1.800.000
# 10673     8             1.300.000         1.500.000       NaN      1.800.000
# 10674    33             1.300.000         1.500.000       NaN      1.800.000
# 10675    71             1.300.000         1.500.000       NaN      1.800.000
#
#                     jumlah_pd_a                       jumlah_pd_b  \
# 0      835  6.305 19.012 26.152                               NaN
# 1                  - 58 470 528                               NaN
# 2                           NaN                               NaN
# 3                   - 4 122 126  1.340.000  1.550.000  1 .860.000
# 4                           NaN                               NaN
# ...                         ...                               ...
# 10671                 6.500.000                        24.000.000
# 10672                         -                        22.500.000
# 10673                         -                                 -
# 10674                 1.300.000                        28.500.000
# 10675                 3.900.000                        19.500.000
#
#          jumlah_pd_c                               jumlah_pd_total  \
# 0      1.122.300.000  9.633.180.000  34.788.860.000 45.544.340.000
# 1                  -            89.900.000 874.200.000 964.100.000
# 2                NaN                                           NaN
# 3                  -             6.200.000 226.920.000 233.120.000
# 4                NaN                                           NaN
# ...              ...                                           ...
# 10671    102.600.000                                    93.600.000
# 10672     97.200.000                                    93.600.000
# 10673     14.400.000                                    93.600.000
# 10674     23.400.000                                    93.600.000
# 10675     99.000.000                                    93.600.000
#
#       satuan_biaya_a                      satuan_biaya_b satuan_biaya_c  \
# 0                NaN                                 NaN            NaN
# 1                NaN                                 NaN            NaN
# 2                NaN                                 NaN            NaN
# 3                NaN                                 NaN            NaN
# 4                NaN                                 NaN            NaN
# ...              ...                                 ...            ...
# 10671            NaN  Pusat Kegiatan\rBelajar Masyarakat       P2965021
# 10672            NaN  Pusat Kegiatan\rBelajar Masyarakat       P2966884
# 10673            NaN  Pusat Kegiatan\rBelajar Masyarakat       P9934457
# 10674            NaN  Pusat Kegiatan\rBelajar Masyarakat       P9984821
# 10675            NaN  Pusat Kegiatan\rBelajar Masyarakat       P9998551
#
#                         alokasi_satu_tahun_a alokasi_satu_tahun_b  \
# 0                                        NaN                  NaN
# 1                                        NaN                  NaN
# 2                                        NaN                  NaN
# 3                                        NaN                  NaN
# 4                                        NaN                  NaN
# ...                                      ...                  ...
# 10671                            PKBM CAHAYA                    5
# 10672                        PKBM WIRABANGSA                    -
# 10673                             PKBM BUNDA                    -
# 10674        PKBM SRI MELAYU\rSUMATERA TIMUR                    1
# 10675  PKBM SWASTA\rRAUDHATUL\rHASANAH KARIM                    3
#
#       alokasi_satu_tahun_c alokasi_satu_tahun_total
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
# ...                    ...                      ...
# 10671                   16                       57
# 10672                   15                       54
# 10673                    -                        8
# 10674                   19                       13
# 10675                   13                       55
#
# [10676 rows x 16 columns]

# %%
pdf_tabel = pdf_tabel.drop(0)
pdf_tabel = pdf_tabel.reset_index(drop=True)

# %%
pdf_tabel
# Out:
#        nomor               wilayah          bentuk_pendidikan      npsn  \
# 0          1         Provinsi Aceh                        NaN       NaN
# 1        NaN  Kabupaten Aceh Barat                        NaN       NaN
# 2        NaN                   NaN              Sekolah Dasar  10107828
# 3        NaN                   NaN              Sekolah Dasar  10107829
# 4        NaN                   NaN              Sekolah Dasar  10107830
# ...      ...                   ...                        ...       ...
# 226199   NaN                   NaN  Sekolah Menengah Kejuruan  69840940
# 226200   NaN                   NaN  Sekolah Menengah Kejuruan  69916026
# 226201   NaN                   NaN         Sekolah Luar Biasa  10211532
# 226202   NaN                   NaN         Sekolah Luar Biasa  69886466
# 226203   NaN                   NaN         Sekolah Luar Biasa  69896658
#
#                              nama_sekolah jumlah_siswa       satuan_biaya  \
# 0                                 882.520          NaN  1.041.073.930.000
# 1                                  30.042          NaN     38.930.680.000
# 2                SD MUHAMMADIYAH MEULABOH           43          1.010.000
# 3                   SD NEGERI 11 MEULABOH           97          1.010.000
# 4                   SD NEGERI 12 MEULABOH          247          1.010.000
# ...                                   ...          ...                ...
# 226199  SMK SWASTA KESEHATAN GANDA HUSADA          208          1.600.000
# 226200            SMK SWASTA R.A. KARTINI          197          1.600.000
# 226201           SLB Negeri Tebing Tinggi          121          3.500.000
# 226202     SLB SWASTA YAPSI TEBING TINGGI          154          3.500.000
# 226203               SLB SWASTA KASIH IBU          141          3.500.000
#
#        total_alokasi
# 0                NaN
# 1                NaN
# 2         43.430.000
# 3         97.970.000
# 4        249.470.000
# ...              ...
# 226199   332.800.000
# 226200   315.200.000
# 226201   423.500.000
# 226202   539.000.000
# 226203   493.500.000
#
# [226204 rows x 8 columns]

# %%
# Remove dots and convert to numeric
pdf_tabel['jumlah_siswa'] = pd.to_numeric(pdf_tabel['jumlah_siswa'].str.replace('.', ''), errors='coerce')
pdf_tabel['satuan_biaya'] = pd.to_numeric(pdf_tabel['satuan_biaya'].str.replace('.', ''), errors='coerce')
pdf_tabel['total_alokasi'] = pd.to_numeric(pdf_tabel['total_alokasi'].str.replace('.', ''), errors='coerce')

# %%
# Save to pickle format
pdf_tabel.to_pickle('pdf_tabel_bop_kesetaraan_1.pkl')

# Save to feather format
pdf_tabel.to_feather('pdf_tabel_bop_kesetaraan_1.feather')

# %%
pdf_tabel
# Out:
#        nomor               wilayah          bentuk_pendidikan      npsn  \
# 0          1         Provinsi Aceh                        NaN       NaN
# 1        NaN  Kabupaten Aceh Barat                        NaN       NaN
# 2        NaN                   NaN              Sekolah Dasar  10107828
# 3        NaN                   NaN              Sekolah Dasar  10107829
# 4        NaN                   NaN              Sekolah Dasar  10107830
# ...      ...                   ...                        ...       ...
# 226199   NaN                   NaN  Sekolah Menengah Kejuruan  69840940
# 226200   NaN                   NaN  Sekolah Menengah Kejuruan  69916026
# 226201   NaN                   NaN         Sekolah Luar Biasa  10211532
# 226202   NaN                   NaN         Sekolah Luar Biasa  69886466
# 226203   NaN                   NaN         Sekolah Luar Biasa  69896658
#
#                              nama_sekolah  jumlah_siswa  satuan_biaya  \
# 0                                 882.520           NaN  1.041074e+12
# 1                                  30.042           NaN  3.893068e+10
# 2                SD MUHAMMADIYAH MEULABOH          43.0  1.010000e+06
# 3                   SD NEGERI 11 MEULABOH          97.0  1.010000e+06
# 4                   SD NEGERI 12 MEULABOH         247.0  1.010000e+06
# ...                                   ...           ...           ...
# 226199  SMK SWASTA KESEHATAN GANDA HUSADA         208.0  1.600000e+06
# 226200            SMK SWASTA R.A. KARTINI         197.0  1.600000e+06
# 226201           SLB Negeri Tebing Tinggi         121.0  3.500000e+06
# 226202     SLB SWASTA YAPSI TEBING TINGGI         154.0  3.500000e+06
# 226203               SLB SWASTA KASIH IBU         141.0  3.500000e+06
#
#         total_alokasi                 province
# 0                 NaN            Provinsi Aceh
# 1                 NaN            Provinsi Aceh
# 2          43430000.0            Provinsi Aceh
# 3          97970000.0            Provinsi Aceh
# 4         249470000.0            Provinsi Aceh
# ...               ...                      ...
# 226199    332800000.0  Provinsi Sumatera Utara
# 226200    315200000.0  Provinsi Sumatera Utara
# 226201    423500000.0  Provinsi Sumatera Utara
# 226202    539000000.0  Provinsi Sumatera Utara
# 226203    493500000.0  Provinsi Sumatera Utara
#
# [226204 rows x 9 columns]

# %%
# Create a new column 'province'
pdf_tabel['province'] = None

# Initialize current_province
current_province = None

# Iterate through rows
for idx, row in pdf_tabel.iterrows():
    if isinstance(row['wilayah'], str) and 'Provinsi' in row['wilayah']:
        current_province = row['wilayah']
    pdf_tabel.at[idx, 'province'] = current_province

# %%
pdf_tabel
# Out:
#        nomor               wilayah          bentuk_pendidikan      npsn  \
# 0          1         Provinsi Aceh                        NaN       NaN
# 1        NaN  Kabupaten Aceh Barat                        NaN       NaN
# 2        NaN                   NaN              Sekolah Dasar  10107828
# 3        NaN                   NaN              Sekolah Dasar  10107829
# 4        NaN                   NaN              Sekolah Dasar  10107830
# ...      ...                   ...                        ...       ...
# 226199   NaN                   NaN  Sekolah Menengah Kejuruan  69840940
# 226200   NaN                   NaN  Sekolah Menengah Kejuruan  69916026
# 226201   NaN                   NaN         Sekolah Luar Biasa  10211532
# 226202   NaN                   NaN         Sekolah Luar Biasa  69886466
# 226203   NaN                   NaN         Sekolah Luar Biasa  69896658
#
#                              nama_sekolah  jumlah_siswa  satuan_biaya  \
# 0                                 882.520           NaN  1.041074e+12
# 1                                  30.042           NaN  3.893068e+10
# 2                SD MUHAMMADIYAH MEULABOH          43.0  1.010000e+06
# 3                   SD NEGERI 11 MEULABOH          97.0  1.010000e+06
# 4                   SD NEGERI 12 MEULABOH         247.0  1.010000e+06
# ...                                   ...           ...           ...
# 226199  SMK SWASTA KESEHATAN GANDA HUSADA         208.0  1.600000e+06
# 226200            SMK SWASTA R.A. KARTINI         197.0  1.600000e+06
# 226201           SLB Negeri Tebing Tinggi         121.0  3.500000e+06
# 226202     SLB SWASTA YAPSI TEBING TINGGI         154.0  3.500000e+06
# 226203               SLB SWASTA KASIH IBU         141.0  3.500000e+06
#
#         total_alokasi                 province
# 0                 NaN            Provinsi Aceh
# 1                 NaN            Provinsi Aceh
# 2          43430000.0            Provinsi Aceh
# 3          97970000.0            Provinsi Aceh
# 4         249470000.0            Provinsi Aceh
# ...               ...                      ...
# 226199    332800000.0  Provinsi Sumatera Utara
# 226200    315200000.0  Provinsi Sumatera Utara
# 226201    423500000.0  Provinsi Sumatera Utara
# 226202    539000000.0  Provinsi Sumatera Utara
# 226203    493500000.0  Provinsi Sumatera Utara
#
# [226204 rows x 9 columns]

# %%
# Create a new column 'province'
pdf_tabel['regency'] = None

# Initialize current_province
current_regency = None

# Iterate through rows
for idx, row in pdf_tabel.iterrows():
    if isinstance(row['wilayah'], str) and ('Kabupaten' in row['wilayah'] or 'Kota' in row['wilayah']):
        current_regency = row['wilayah']
    pdf_tabel.at[idx, 'regency'] = current_regency

# %%
pdf_tabel
# Out:
#        nomor               wilayah          bentuk_pendidikan      npsn  \
# 0          1         Provinsi Aceh                        NaN       NaN
# 1        NaN  Kabupaten Aceh Barat                        NaN       NaN
# 2        NaN                   NaN              Sekolah Dasar  10107828
# 3        NaN                   NaN              Sekolah Dasar  10107829
# 4        NaN                   NaN              Sekolah Dasar  10107830
# ...      ...                   ...                        ...       ...
# 226199   NaN                   NaN  Sekolah Menengah Kejuruan  69840940
# 226200   NaN                   NaN  Sekolah Menengah Kejuruan  69916026
# 226201   NaN                   NaN         Sekolah Luar Biasa  10211532
# 226202   NaN                   NaN         Sekolah Luar Biasa  69886466
# 226203   NaN                   NaN         Sekolah Luar Biasa  69896658
#
#                              nama_sekolah  jumlah_siswa  satuan_biaya  \
# 0                                 882.520           NaN  1.041074e+12
# 1                                  30.042           NaN  3.893068e+10
# 2                SD MUHAMMADIYAH MEULABOH          43.0  1.010000e+06
# 3                   SD NEGERI 11 MEULABOH          97.0  1.010000e+06
# 4                   SD NEGERI 12 MEULABOH         247.0  1.010000e+06
# ...                                   ...           ...           ...
# 226199  SMK SWASTA KESEHATAN GANDA HUSADA         208.0  1.600000e+06
# 226200            SMK SWASTA R.A. KARTINI         197.0  1.600000e+06
# 226201           SLB Negeri Tebing Tinggi         121.0  3.500000e+06
# 226202     SLB SWASTA YAPSI TEBING TINGGI         154.0  3.500000e+06
# 226203               SLB SWASTA KASIH IBU         141.0  3.500000e+06
#
#         total_alokasi                 province               regency
# 0                 NaN            Provinsi Aceh                  None
# 1                 NaN            Provinsi Aceh  Kabupaten Aceh Barat
# 2          43430000.0            Provinsi Aceh  Kabupaten Aceh Barat
# 3          97970000.0            Provinsi Aceh  Kabupaten Aceh Barat
# 4         249470000.0            Provinsi Aceh  Kabupaten Aceh Barat
# ...               ...                      ...                   ...
# 226199    332800000.0  Provinsi Sumatera Utara    Kota Tebing Tinggi
# 226200    315200000.0  Provinsi Sumatera Utara    Kota Tebing Tinggi
# 226201    423500000.0  Provinsi Sumatera Utara    Kota Tebing Tinggi
# 226202    539000000.0  Provinsi Sumatera Utara    Kota Tebing Tinggi
# 226203    493500000.0  Provinsi Sumatera Utara    Kota Tebing Tinggi
#
# [226204 rows x 10 columns]

# %%
# Remove rows where npsn column contains "(d)"
pdf_tabel = pdf_tabel[pdf_tabel['npsn'] != "(d)"]
# Reset index after removing rows
pdf_tabel = pdf_tabel.reset_index(drop=True)

# %%
# Remove rows where bentuk_pendidikan is NaN
pdf_tabel = pdf_tabel[pd.notna(pdf_tabel['bentuk_pendidikan'])]
# Reset index after removing rows 
pdf_tabel = pdf_tabel.reset_index(drop=True)

# %%
pdf_tabel
# Out:
#        nomor wilayah          bentuk_pendidikan      npsn  \
# 0        NaN     NaN              Sekolah Dasar  10107828
# 1        NaN     NaN              Sekolah Dasar  10107829
# 2        NaN     NaN              Sekolah Dasar  10107830
# 3        NaN     NaN              Sekolah Dasar  10107831
# 4        NaN     NaN              Sekolah Dasar  10107832
# ...      ...     ...                        ...       ...
# 219694   NaN     NaN  Sekolah Menengah Kejuruan  69840940
# 219695   NaN     NaN  Sekolah Menengah Kejuruan  69916026
# 219696   NaN     NaN         Sekolah Luar Biasa  10211532
# 219697   NaN     NaN         Sekolah Luar Biasa  69886466
# 219698   NaN     NaN         Sekolah Luar Biasa  69896658
#
#                              nama_sekolah  jumlah_siswa  satuan_biaya  \
# 0                SD MUHAMMADIYAH MEULABOH          43.0     1010000.0
# 1                   SD NEGERI 11 MEULABOH          97.0     1010000.0
# 2                   SD NEGERI 12 MEULABOH         247.0     1010000.0
# 3                   SD NEGERI 13 MEULABOH         126.0     1010000.0
# 4                   SD NEGERI 14 MEULABOH         440.0     1010000.0
# ...                                   ...           ...           ...
# 219694  SMK SWASTA KESEHATAN GANDA HUSADA         208.0     1600000.0
# 219695            SMK SWASTA R.A. KARTINI         197.0     1600000.0
# 219696           SLB Negeri Tebing Tinggi         121.0     3500000.0
# 219697     SLB SWASTA YAPSI TEBING TINGGI         154.0     3500000.0
# 219698               SLB SWASTA KASIH IBU         141.0     3500000.0
#
#         total_alokasi                 province               regency
# 0          43430000.0            Provinsi Aceh  Kabupaten Aceh Barat
# 1          97970000.0            Provinsi Aceh  Kabupaten Aceh Barat
# 2         249470000.0            Provinsi Aceh  Kabupaten Aceh Barat
# 3         127260000.0            Provinsi Aceh  Kabupaten Aceh Barat
# 4         444400000.0            Provinsi Aceh  Kabupaten Aceh Barat
# ...               ...                      ...                   ...
# 219694    332800000.0  Provinsi Sumatera Utara    Kota Tebing Tinggi
# 219695    315200000.0  Provinsi Sumatera Utara    Kota Tebing Tinggi
# 219696    423500000.0  Provinsi Sumatera Utara    Kota Tebing Tinggi
# 219697    539000000.0  Provinsi Sumatera Utara    Kota Tebing Tinggi
# 219698    493500000.0  Provinsi Sumatera Utara    Kota Tebing Tinggi
#
# [219699 rows x 10 columns]

# %%
# Save to pickle format
pdf_tabel[['wilayah', 'bentuk_pendidikan', 'npsn', 'nama_sekolah', 'jumlah_siswa', 'satuan_biaya', 'total_alokasi', 'province', 'regency']].to_pickle('pdf_tabel_bop_kesetaraan_clean.pkl')

# Save to feather format
pdf_tabel[['wilayah', 'bentuk_pendidikan', 'npsn', 'nama_sekolah', 'jumlah_siswa', 'satuan_biaya', 'total_alokasi', 'province', 'regency']].to_feather('pdf_tabel_bop_kesetaraan_clean.feather')

# %%
df_bos_reguler_2024 = pdf_tabel[['bentuk_pendidikan', 'npsn', 'nama_sekolah', 'jumlah_siswa', 'satuan_biaya', 'total_alokasi', 'province', 'regency']].copy()

# %%
df_bos_reguler_2024
# Out:
#                 bentuk_pendidikan      npsn  \
# 0                   Sekolah Dasar  10107828
# 1                   Sekolah Dasar  10107829
# 2                   Sekolah Dasar  10107830
# 3                   Sekolah Dasar  10107831
# 4                   Sekolah Dasar  10107832
# ...                           ...       ...
# 219694  Sekolah Menengah Kejuruan  69840940
# 219695  Sekolah Menengah Kejuruan  69916026
# 219696         Sekolah Luar Biasa  10211532
# 219697         Sekolah Luar Biasa  69886466
# 219698         Sekolah Luar Biasa  69896658
#
#                              nama_sekolah  jumlah_siswa  satuan_biaya  \
# 0                SD MUHAMMADIYAH MEULABOH          43.0     1010000.0
# 1                   SD NEGERI 11 MEULABOH          97.0     1010000.0
# 2                   SD NEGERI 12 MEULABOH         247.0     1010000.0
# 3                   SD NEGERI 13 MEULABOH         126.0     1010000.0
# 4                   SD NEGERI 14 MEULABOH         440.0     1010000.0
# ...                                   ...           ...           ...
# 219694  SMK SWASTA KESEHATAN GANDA HUSADA         208.0     1600000.0
# 219695            SMK SWASTA R.A. KARTINI         197.0     1600000.0
# 219696           SLB Negeri Tebing Tinggi         121.0     3500000.0
# 219697     SLB SWASTA YAPSI TEBING TINGGI         154.0     3500000.0
# 219698               SLB SWASTA KASIH IBU         141.0     3500000.0
#
#         total_alokasi                 province               regency
# 0          43430000.0            Provinsi Aceh  Kabupaten Aceh Barat
# 1          97970000.0            Provinsi Aceh  Kabupaten Aceh Barat
# 2         249470000.0            Provinsi Aceh  Kabupaten Aceh Barat
# 3         127260000.0            Provinsi Aceh  Kabupaten Aceh Barat
# 4         444400000.0            Provinsi Aceh  Kabupaten Aceh Barat
# ...               ...                      ...                   ...
# 219694    332800000.0  Provinsi Sumatera Utara    Kota Tebing Tinggi
# 219695    315200000.0  Provinsi Sumatera Utara    Kota Tebing Tinggi
# 219696    423500000.0  Provinsi Sumatera Utara    Kota Tebing Tinggi
# 219697    539000000.0  Provinsi Sumatera Utara    Kota Tebing Tinggi
# 219698    493500000.0  Provinsi Sumatera Utara    Kota Tebing Tinggi
#
# [219699 rows x 8 columns]

# %%
#df_bos_reguler_2024.to_excel('alokasi_bos_reguler_2024.xlsx', index=False)
